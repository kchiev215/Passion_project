# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %%bash
# ls
# Out:
# ClimbingLogBook.zip
# DE Web Scraping.ipynb
# Data Analysis.ipynb
# Description_tables
# Location_DB.ipynb
# MP_CSV
# NJ Mid Web scraping.ipynb
# NJ South Web scraping.ipynb
# PA Web scraping.ipynb
# combined_route_chart.csv
# database.sqlite

# %%
PA_boulders = pd.read_csv('/Users/Thina/Desktop/Passionproject/Description_tables/combined_PA.csv')
PA_boulders['State'] = 'PA'
PA_boulders
# Out:
#      Unnamed: 0  index                           Route  \
# 0             0      0                         Falling
# 1             1      1                  Mickeys Mantle
# 2             2      2                 Warmup Traverse
# 3             3      3                      Crank N Up
# 4             4      4                        Bootwear
# ..          ...    ...                             ...
# 534         534    534                          Machop
# 535         535    535                    Seven Angels
# 536         536    536                  Sunshine Arete
# 537         537    537  Teeth Of Lions Rule The Divine
# 538         538    538              Boat Wall Traverse
#
#                                               Location  \
# 0    a. Descent Trail Area > Ralph Stover State Par...
# 1    b. Practice Face > Ralph Stover State Park (Hi...
# 2    b. Practice Face > Ralph Stover State Park (Hi...
# 3    b. Practice Face > Ralph Stover State Park (Hi...
# 4    c. Neolithic Wall > Ralph Stover State Park (H...
# ..                                                 ...
# 534  Sunshine Boulders > Crum Woods > Southeastern ...
# 535  Sunshine Boulders > Crum Woods > Southeastern ...
# 536  Sunshine Boulders > Crum Woods > Southeastern ...
# 537  Sunshine Boulders > Crum Woods > Southeastern ...
# 538  Tyler Park Bouldering > Southeastern Lowlands ...
#
#                                                    URL  Avg Stars  Your Stars  \
# 0    https://www.mountainproject.com/route/10613457...        1.7          -1
# 1    https://www.mountainproject.com/route/10613504...        2.0          -1
# 2    https://www.mountainproject.com/route/10613504...       -1.0          -1
# 3    https://www.mountainproject.com/route/10613503...       -1.0          -1
# 4    https://www.mountainproject.com/route/10613508...        1.0          -1
# ..                                                 ...        ...         ...
# 534  https://www.mountainproject.com/route/11914213...        2.0          -1
# 535  https://www.mountainproject.com/route/11914203...        2.0          -1
# 536  https://www.mountainproject.com/route/11914184...        1.0          -1
# 537  https://www.mountainproject.com/route/11914205...        2.5          -1
# 538  https://www.mountainproject.com/route/12219503...        2.0          -1
#
#     Route Type   Rating  Pitches  Length  Area Latitude  Area Longitude  \
# 0      Boulder    V0+ R        1     NaN       40.44063       -75.09975
# 1      Boulder       V0        1     NaN       40.44047       -75.09940
# 2      Boulder      V0+        1     NaN       40.44047       -75.09940
# 3      Boulder      V0+        1     NaN       40.44047       -75.09940
# 4      Boulder       V4        1     NaN       40.44066       -75.09934
# ..         ...      ...      ...     ...            ...             ...
# 534    Boulder       V0        1     NaN       39.90355       -75.35887
# 535    Boulder   V0-1 R        1     NaN       39.90355       -75.35887
# 536    Boulder      V1-        1     NaN       39.90355       -75.35887
# 537    Boulder   V1-2 R        1     NaN       39.90355       -75.35887
# 538    Boulder  V0 PG13        1    12.0       40.22561       -74.96258
#
#                                            Description State
# 0    A roof problem on the detached outcrop at the ...    PA
# 1    Pull the overhang onto an awkward, sloping ledge.    PA
# 2    Begin at the Practice Chimney and climb down a...    PA
# 3    Reach up for the jug and climb the arete for 5...    PA
# 4    Climb the blank face betwen two cracks to a sm...    PA
# ..                                                 ...   ...
# 534  SDS on far right of overhang. Traverse left as...    PA
# 535  SDS and climb the left arête. A fall on this r...    PA
# 536  SDS matched low on the arête. Climb the arête,...    PA
# 537  SDS in middle of face. Climb straight up witho...    PA
# 538  Start on the good jug on the left side of the ...    PA
#
# [539 rows x 15 columns]

# %%
Delaware_Boulders = pd.read_csv('/Users/Thina/Desktop/Passionproject/Description_tables/combined_DE.csv')

Delaware_Boulders
# Out:
#     Unnamed: 0  index                         Route  \
# 0            0      0              Warm Up Traverse
# 1            1      1     Grey Streak Or Temptation
# 2            2      2                         Rambo
# 3            3      3            A Bit Tall To Fall
# 4            4      4                Heat Index 110
# 5            5      5  Martha Stewarts Donut Fetish
# 6            6      6                 Chim Chiminey
# 7            7      7         A Balance Of Question
# 8            8      8                     Paha Sapa
# 9            9      9                        Ransom
# 10          10     10                 Faint Whimper
# 11          11     11           Failed Negotiations
# 12          12     12                     Bad Ideas
# 13          13     13              Winter Seasoning
# 14          14     14                     Scar Face
# 15          15     15                    Lithe Wire
# 16          16     16                       Hostage
# 17          17     17                         Arete
# 18          18     18             Over The Hump Day
# 19          19     19                Hump Extension
# 20          20     20              The Starr Report
# 21          21     21          Easy Streetdownclimb
# 22          22     22                     Spackleft
# 23          23     23                   Spacklehead
# 24          24     24              Positive Contact
# 25          25     25               Stache Traverse
# 26          26     26                  Movin To Cdh
# 27          27     27            Spacklehead Direct
# 28          28     28                    Warm Me Up
# 29          29     29                 Balancing Act
# 30          30     30                     Blood Tax
# 31          31     31   The Devil Is In The Details
# 32          32     32                     Backboard
# 33          33     33                       Windome
# 34          34     34                  Black Friday
# 35          35     35                 Backboard Sds
# 36          36     36                  Air Delaware
# 37          37     37                       Flapper
# 38          38     38               Wagging The Dog
# 39          39     39                    Tree Route
# 40          40     40                     Powerball
# 41          41     41             Dollar Store Bong
# 42          42     42               Corporate Blues
# 43          43     43                 Creative Mind
# 44          44     44                   Homesteader
# 45          45     45                Mama The Shama
# 46          46     46          Non Phallic Eggplant
# 47          47     47              Roughed The Butt
# 48          48     48         Truck Nuts On A Prius
# 49          49     49                  Flex A Flake
# 50          50     50            Beneath The Cheeks
# 51          51     51                      Rib Cage
# 52          52     52              Front And Center
# 53          53     53             Not The Backboard
# 54          54     54                Good Dirty Fun
#
#                                              Location  \
# 0   Main Roped Climbing Wall > Alapocas Run State ...
# 1   Main Roped Climbing Wall > Alapocas Run State ...
# 2   Main Roped Climbing Wall > Alapocas Run State ...
# 3      Heat Index Boulders > Rockford Park > Delaware
# 4      Heat Index Boulders > Rockford Park > Delaware
# 5      Heat Index Boulders > Rockford Park > Delaware
# 6      Heat Index Boulders > Rockford Park > Delaware
# 7      Heat Index Boulders > Rockford Park > Delaware
# 8      Heat Index Boulders > Rockford Park > Delaware
# 9        Spearhead Boulder > Rockford Park > Delaware
# 10       Spearhead Boulder > Rockford Park > Delaware
# 11       Spearhead Boulder > Rockford Park > Delaware
# 12       Spearhead Boulder > Rockford Park > Delaware
# 13       Spearhead Boulder > Rockford Park > Delaware
# 14       Spearhead Boulder > Rockford Park > Delaware
# 15       Spearhead Boulder > Rockford Park > Delaware
# 16       Spearhead Boulder > Rockford Park > Delaware
# 17       Spearhead Boulder > Rockford Park > Delaware
# 18       Spearhead Boulder > Rockford Park > Delaware
# 19       Spearhead Boulder > Rockford Park > Delaware
# 20       Spearhead Boulder > Rockford Park > Delaware
# 21     Spacklehead Boulder > Rockford Park > Delaware
# 22     Spacklehead Boulder > Rockford Park > Delaware
# 23     Spacklehead Boulder > Rockford Park > Delaware
# 24     Spacklehead Boulder > Rockford Park > Delaware
# 25     Spacklehead Boulder > Rockford Park > Delaware
# 26     Spacklehead Boulder > Rockford Park > Delaware
# 27     Spacklehead Boulder > Rockford Park > Delaware
# 28     Black Widow Boulder > Rockford Park > Delaware
# 29     Black Widow Boulder > Rockford Park > Delaware
# 30     Black Widow Boulder > Rockford Park > Delaware
# 31     Black Widow Boulder > Rockford Park > Delaware
# 32  Scattered Small Boulders > Rockford Park > Del...
# 33  Scattered Small Boulders > Rockford Park > Del...
# 34  Scattered Small Boulders > Rockford Park > Del...
# 35  Scattered Small Boulders > Rockford Park > Del...
# 36  Scattered Small Boulders > Rockford Park > Del...
# 37  Scattered Small Boulders > Rockford Park > Del...
# 38  Scattered Small Boulders > Rockford Park > Del...
# 39    Makeout Cave Cluster > Rockford Park > Delaware
# 40    Makeout Cave Cluster > Rockford Park > Delaware
# 41              Lower Tier > Rockford Park > Delaware
# 42              Lower Tier > Rockford Park > Delaware
# 43              Lower Tier > Rockford Park > Delaware
# 44              Lower Tier > Rockford Park > Delaware
# 45              Lower Tier > Rockford Park > Delaware
# 46              Lower Tier > Rockford Park > Delaware
# 47              Lower Tier > Rockford Park > Delaware
# 48              Lower Tier > Rockford Park > Delaware
# 49              Lower Tier > Rockford Park > Delaware
# 50              Lower Tier > Rockford Park > Delaware
# 51          Rockwood Park / Greenway Trail > Delaware
# 52  Front and Center Boulder > Brandywine Park > D...
# 53  Front and Center Boulder > Brandywine Park > D...
# 54  Front and Center Boulder > Brandywine Park > D...
#
#                                                   URL  Avg Stars  Your Stars  \
# 0   https://www.mountainproject.com/route/10748302...        2.3          -1
# 1   https://www.mountainproject.com/route/11663460...        2.8          -1
# 2   https://www.mountainproject.com/route/11817760...        3.5          -1
# 3   https://www.mountainproject.com/route/12081411...        2.0          -1
# 4   https://www.mountainproject.com/route/11534212...        1.5          -1
# 5   https://www.mountainproject.com/route/12081412...        2.5          -1
# 6   https://www.mountainproject.com/route/11534215...        2.0          -1
# 7   https://www.mountainproject.com/route/11534213...        2.0          -1
# 8   https://www.mountainproject.com/route/11534218...        0.0          -1
# 9   https://www.mountainproject.com/route/11666268...        2.0          -1
# 10  https://www.mountainproject.com/route/12040876...        2.0          -1
# 11  https://www.mountainproject.com/route/12040874...        2.0          -1
# 12  https://www.mountainproject.com/route/12040875...        2.0          -1
# 13  https://www.mountainproject.com/route/11803494...        3.2          -1
# 14  https://www.mountainproject.com/route/11986910...        2.0          -1
# 15  https://www.mountainproject.com/route/11803497...        2.0          -1
# 16  https://www.mountainproject.com/route/11666265...        3.5          -1
# 17  https://www.mountainproject.com/route/11992736...        4.0          -1
# 18  https://www.mountainproject.com/route/11986913...        2.0          -1
# 19  https://www.mountainproject.com/route/12021684...        3.0          -1
# 20  https://www.mountainproject.com/route/11986909...        3.0          -1
# 21  https://www.mountainproject.com/route/11803503...        2.0          -1
# 22  https://www.mountainproject.com/route/12082317...        3.0          -1
# 23  https://www.mountainproject.com/route/11654743...        2.8          -1
# 24  https://www.mountainproject.com/route/11654749...        2.0          -1
# 25  https://www.mountainproject.com/route/11654752...        3.0          -1
# 26  https://www.mountainproject.com/route/11806946...        4.0          -1
# 27  https://www.mountainproject.com/route/12010370...        3.0          -1
# 28  https://www.mountainproject.com/route/12196205...        3.0          -1
# 29  https://www.mountainproject.com/route/12196209...        3.0          -1
# 30  https://www.mountainproject.com/route/11660726...        2.4          -1
# 31  https://www.mountainproject.com/route/12238151...        3.0          -1
# 32  https://www.mountainproject.com/route/11803500...        3.0          -1
# 33  https://www.mountainproject.com/route/12065921...        2.0          -1
# 34  https://www.mountainproject.com/route/11804971...        2.0          -1
# 35  https://www.mountainproject.com/route/12081415...        3.5          -1
# 36  https://www.mountainproject.com/route/11811864...        2.0          -1
# 37  https://www.mountainproject.com/route/11811852...        3.0          -1
# 38  https://www.mountainproject.com/route/11982270...        3.0          -1
# 39  https://www.mountainproject.com/route/11804884...        1.0          -1
# 40  https://www.mountainproject.com/route/11804878...        3.0          -1
# 41  https://www.mountainproject.com/route/12067627...        1.0          -1
# 42  https://www.mountainproject.com/route/12072802...        2.0          -1
# 43  https://www.mountainproject.com/route/12072806...        1.5          -1
# 44  https://www.mountainproject.com/route/12072811...        2.0          -1
# 45  https://www.mountainproject.com/route/12067621...        2.5          -1
# 46  https://www.mountainproject.com/route/12132497...        2.0          -1
# 47  https://www.mountainproject.com/route/12072808...        3.5          -1
# 48  https://www.mountainproject.com/route/12132478...        3.0          -1
# 49  https://www.mountainproject.com/route/12072802...        3.0          -1
# 50  https://www.mountainproject.com/route/12072811...        3.0          -1
# 51  https://www.mountainproject.com/route/11894051...        2.0          -1
# 52  https://www.mountainproject.com/route/12081417...        2.5          -1
# 53  https://www.mountainproject.com/route/12081421...        3.0          -1
# 54  https://www.mountainproject.com/route/12081419...        3.0          -1
#
#      Route Type     Rating  Pitches  Length  Area Latitude  Area Longitude  \
# 0       Boulder        V0+        1     NaN       39.76909       -75.55829
# 1   TR, Boulder   5.10d V2        1    20.0       39.76909       -75.55829
# 2   TR, Boulder   5.12a V4        1    20.0       39.76909       -75.55829
# 3       Boulder    V0 PG13        1    18.0       39.76818       -75.57450
# 4       Boulder         V0        1    20.0       39.76818       -75.57450
# 5       Boulder    V0 PG13        1    18.0       39.76818       -75.57450
# 6       Boulder         V0        1    25.0       39.76818       -75.57450
# 7       Boulder        V0+        1    25.0       39.76818       -75.57450
# 8       Boulder        V0+        1     8.0       39.76818       -75.57450
# 9       Boulder         V0        1    11.0       39.76852       -75.57409
# 10  TR, Boulder    V0 PG13        1    18.0       39.76852       -75.57409
# 11  TR, Boulder     V0-1 R        1    15.0       39.76852       -75.57409
# 12  TR, Boulder     V0-1 R        1    15.0       39.76852       -75.57409
# 13      Boulder         V1        1    12.0       39.76852       -75.57409
# 14      Boulder         V1        1    10.0       39.76852       -75.57409
# 15      Boulder        V2-        1    12.0       39.76852       -75.57409
# 16      Boulder         V3        1    16.0       39.76852       -75.57409
# 17      Boulder        V3+        1    10.0       39.76852       -75.57409
# 18      Boulder         V4        1    10.0       39.76852       -75.57409
# 19      Boulder        V4+        1     NaN       39.76852       -75.57409
# 20      Boulder         V5        1    10.0       39.76852       -75.57409
# 21      Boulder         V0        1    12.0       39.76826       -75.57481
# 22      Boulder         V1        1     NaN       39.76826       -75.57481
# 23      Boulder         V2        1     8.0       39.76826       -75.57481
# 24      Boulder        V2+        1     8.0       39.76826       -75.57481
# 25      Boulder         V3        1    15.0       39.76826       -75.57481
# 26      Boulder    V3 PG13        1    18.0       39.76826       -75.57481
# 27      Boulder        V4+        1    10.0       39.76826       -75.57481
# 28      Boulder     V-easy        1    12.0       39.76835       -75.57419
# 29      Boulder        V1-        1    11.0       39.76835       -75.57419
# 30      Boulder        V2+        1     8.0       39.76835       -75.57419
# 31      Boulder         V7        1    15.0       39.76835       -75.57419
# 32      Boulder         V0        1     8.0       39.76831       -75.57451
# 33      Boulder         V1        1    10.0       39.76831       -75.57451
# 34      Boulder         V1        1     8.0       39.76831       -75.57451
# 35      Boulder        V1+        1    10.0       39.76831       -75.57451
# 36      Boulder       V2-3        1    10.0       39.76831       -75.57451
# 37      Boulder       V3-4        1    10.0       39.76831       -75.57451
# 38      Boulder         V4        1    10.0       39.76831       -75.57451
# 39      Boulder         V0        1     8.0       39.76833       -75.57495
# 40      Boulder         V2        1    12.0       39.76833       -75.57495
# 41      Boulder        V0-        1    12.0       39.76853       -75.57480
# 42      Boulder        V1-        1    10.0       39.76853       -75.57480
# 43      Boulder         V1        1    10.0       39.76853       -75.57480
# 44      Boulder         V1        1    10.0       39.76853       -75.57480
# 45      Boulder         V1        1    12.0       39.76853       -75.57480
# 46      Boulder         V1        1    10.0       39.76853       -75.57480
# 47      Boulder         V2        1    12.0       39.76853       -75.57480
# 48      Boulder         V2        1    25.0       39.76853       -75.57480
# 49      Boulder        V2+        1    12.0       39.76853       -75.57480
# 50      Boulder       V3-4        1    12.0       39.76853       -75.57480
# 51      Boulder  V0-1 PG13        2     8.0       39.77404       -75.51579
# 52      Boulder         V1        1    10.0       39.75675       -75.55106
# 53      Boulder         V1        1     8.0       39.75675       -75.55106
# 54      Boulder         V2        1    10.0       39.75675       -75.55106
#
#                       Route name  \
# 0               Warm Up Traverse
# 1      Grey Streak Or Temptation
# 2                          Rambo
# 3             A Bit Tall To Fall
# 4                 Heat Index 110
# 5   Martha Stewarts Donut Fetish
# 6                  Chim Chiminey
# 7          A Balance Of Question
# 8                      Paha Sapa
# 9                         Ransom
# 10                 Faint Whimper
# 11           Failed Negotiations
# 12                     Bad Ideas
# 13              Winter Seasoning
# 14                     Scar Face
# 15                    Lithe Wire
# 16                       Hostage
# 17                         Arete
# 18             Over The Hump Day
# 19                Hump Extension
# 20              The Starr Report
# 21          Easy Streetdownclimb
# 22                     Spackleft
# 23                   Spacklehead
# 24              Positive Contact
# 25               Stache Traverse
# 26                  Movin To Cdh
# 27            Spacklehead Direct
# 28                    Warm Me Up
# 29                 Balancing Act
# 30                     Blood Tax
# 31   The Devil Is In The Details
# 32                     Backboard
# 33                       Windome
# 34                  Black Friday
# 35                 Backboard Sds
# 36                  Air Delaware
# 37                       Flapper
# 38               Wagging The Dog
# 39                    Tree Route
# 40                     Powerball
# 41             Dollar Store Bong
# 42               Corporate Blues
# 43                 Creative Mind
# 44                   Homesteader
# 45                Mama The Shama
# 46          Non Phallic Eggplant
# 47              Roughed The Butt
# 48         Truck Nuts On A Prius
# 49                  Flex A Flake
# 50            Beneath The Cheeks
# 51                      Rib Cage
# 52              Front And Center
# 53             Not The Backboard
# 54                Good Dirty Fun
#
#                                           Description
# 0   The natural warmup boulder traverse a foot abo...
# 1   Excellent tiny feet and almost impossible hand...
# 2   A former sport climb (rest in peace, homie). A...
# 3   Climb the tall face straight up, skirting righ...
# 4                Climb straight up the 2 tiered face.
# 5   Climb up onto the ledge and then take the insi...
# 6   Back and foot pressure traverse out to overhan...
# 7      Climb the slab, left and right aretes are off.
# 8                               Short mantle problem.
# 9   Start all the way back underneath the left are...
# 10  Climb the left side of the tall slab to the ri...
# 11  Start on top of the block that Hostage, and St...
# 12  Start on the right side of the slab above Host...
# 13  Sit start with hands in the left facing crack....
# 14  Start on good left edge and low side-pull righ...
# 15  Start with smeary feet and lay back tension on...
# 16  Start hanging on the obvious jug about 6ft off...
# 17  Stand start left hand on sloper at head height...
# 18  Start with right hand undercling and left on t...
# 19  Start on hostage (obvious jug in the middle of...
# 20  Start on double undercling and bad feet then m...
# 21  Easiest route on the spacklehead boulder and t...
# 22  Beta break for spacklehead. Probably worth con...
# 23  Start on the lower left edge of the seam on th...
# 24  Start on the right side arete of the backside ...
# 25  Start as for spacklehead but follow the seam u...
# 26  The start is only PG-13 if you don't have a sp...
# 27  Sit start in the center of the face with low r...
# 28  An easy up or down climb.  Great for warmup or...
# 29  Start with your left foot in the obvious cutou...
# 30  Short but very stout. Start with hands on the ...
# 31  Super awesome sustained problem with super spe...
# 32  Sit start with smeary feet and a good flat han...
# 33  Start with wide hands and feet on blocks below...
# 34  Use large holds and smeary feet to climb the s...
# 35  The low sit start to Backboard [V0]. Start in ...
# 36  Sit-start compressing both arete, with creativ...
# 37  Start with hands on the incut dimple at the li...
# 38  Start left hand on the slopey rail and right h...
# 39  Start on the jug edge deep underneath the tree...
# 40  Start on the boulders underneath the cap. Use ...
# 41           Follow slab closest to corner up to top.
# 42  SDS with right hand on undercling and left han...
# 43  Start as for Corporate Blues, but follow seam ...
# 44  SDS by laybacking on crack. Bump up along midd...
# 45  On the left side of boulder, follow the arete ...
# 46  Start with left hand undercling on arete, and ...
# 47  Start on the same jug as flex-a-flake, but go ...
# 48  This problem is a variation/extension to "roug...
# 49  Start matched on the large left facing jug fla...
# 50  A very low sit start to either Flex-a-flake or...
# 51  The crux is the middle of the face, the crack ...
# 52  Start in the very venter of the boulder with h...
# 53  Sit Start with hands on the good blocky ledge....
# 54  Sit start hanging on the good blocky edge belo...

# %%
NJ_MID_boulders = pd.read_csv('/Users/Thina/Desktop/Passionproject/Description_tables/Combined_NJ_MID_boulder.csv')
NJ_MID_boulders
# Out:
#     Unnamed: 0  index               Route  \
# 0            0      0          Polar Bear
# 1            1      1                 Axe
# 2            2      2            Lazy Day
# 3            3      3             Hatchet
# 4            4      4             unnamed
# ..         ...    ...                 ...
# 84          84     84          Misbehavin
# 85          85     85  Richard’s traverse
# 86          86     86  Richard Green Blue
# 87          87     87     Richard’s Crack
# 88          88     88       Rainbow Crack
#
#                                              Location  \
# 0   Southfield > Sourland Mountain Preserve > * bo...
# 1   Southfield > Sourland Mountain Preserve > * bo...
# 2   Southfield > Sourland Mountain Preserve > * bo...
# 3   Southfield > Sourland Mountain Preserve > * bo...
# 4   Southfield > Sourland Mountain Preserve > * bo...
# ..                                                ...
# 84  Spark Wall > Desperation Buildering > * boulde...
# 85  Watergate bouldering > * bouldering mid-state ...
# 86  Watergate bouldering > * bouldering mid-state ...
# 87  Watergate bouldering > * bouldering mid-state ...
# 88  Watergate bouldering > * bouldering mid-state ...
#
#                                                   URL  Avg Stars  Your Stars  \
# 0   https://www.mountainproject.com/route/11178633...        2.7          -1
# 1   https://www.mountainproject.com/route/11178636...        1.4          -1
# 2   https://www.mountainproject.com/route/11178638...        1.6          -1
# 3   https://www.mountainproject.com/route/11796064...        1.7          -1
# 4   https://www.mountainproject.com/route/11133249...        1.0          -1
# ..                                                ...        ...         ...
# 84  https://www.mountainproject.com/route/11886960...        1.0          -1
# 85  https://www.mountainproject.com/route/12227024...        0.5          -1
# 86  https://www.mountainproject.com/route/12227190...        0.5          -1
# 87  https://www.mountainproject.com/route/12227022...        0.5          -1
# 88  https://www.mountainproject.com/route/12227024...        1.0          -1
#
#    Route Type   Rating  Pitches  Length  Area Latitude  Area Longitude  \
# 0     Boulder  V0 PG13        1     NaN       40.47547       -74.70160
# 1     Boulder       V0        1     NaN       40.47547       -74.70160
# 2     Boulder       V0        1     NaN       40.47547       -74.70160
# 3     Boulder       V0        1     NaN       40.47547       -74.70160
# 4     Boulder      V0+        1     NaN       40.47547       -74.70160
# ..        ...      ...      ...     ...            ...             ...
# 84    Boulder      V1+        1    15.0       39.83335       -73.45905
# 85    Boulder       V0        1    25.0       40.38636       -74.22764
# 86    Boulder     V3-4        1    15.0       40.38636       -74.22764
# 87    Boulder     V4-5        1    10.0       40.38636       -74.22764
# 88    Boulder     V5-6        1    35.0       40.38636       -74.22764
#
#             Route name                                        Description
# 0           Polar Bear                                      Not available
# 1                  Axe                                      Not available
# 2             Lazy Day                                      Not available
# 3              Hatchet  Same SDS as Axe to the right of the arête. Mak...
# 4              Unnamed                                      Not available
# ..                 ...                                                ...
# 84          Misbehavin                                      5 or so moves
# 85   Richards Traverse  Very easy, watch out for a small vine hanging ...
# 86  Richard Green Blue  It starts in the middle of the pillar, it is j...
# 87      Richards Crack  On the opposite side of rainbow crack, it star...
# 88       Rainbow Crack  Pretty sharp edges, and a small crux on the pi...
#
# [89 rows x 15 columns]

# %%
NJ_SOUTH_boulders = pd.read_csv('/Users/Thina/Desktop/Passionproject/Description_tables/combined_NJ_south.csv')
NJ_SOUTH_boulders
# Out:
#    Unnamed: 0  index                 Route  \
# 0           0      0  Tanaka's Master Plan
# 1           1      1      Army of the Dead
#
#                                             Location  \
# 0  Tanaka's Bly Tower > Atlantic City > e. South ...
# 1  Tanaka's Bly Tower > Atlantic City > e. South ...
#
#                                                  URL  Avg Stars  Your Stars  \
# 0  https://www.mountainproject.com/route/11786435...        3.0          -1
# 1  https://www.mountainproject.com/route/11786437...        2.0          -1
#
#   Route Type Rating  Pitches  Length  Area Latitude  Area Longitude  \
# 0    Boulder    V0+        1      10       39.37632       -74.41817
# 1    Boulder     V2        1      10       39.37632       -74.41817
#
#             Route name                                        Description
# 0  Tanakas Master Plan  Sit start on the east face of the pillar with ...
# 1     Army Of The Dead  Sit start at the NE arete, with rubber crimp f...

# %%
combined = [NJ_MID_boulders, NJ_SOUTH_boulders, PA_boulders, Delaware_Boulders]
combined_chart = pd.concat(combined)
combined_chart
# Out:
#     Unnamed: 0  index               Route  \
# 0            0      0          Polar Bear
# 1            1      1                 Axe
# 2            2      2            Lazy Day
# 3            3      3             Hatchet
# 4            4      4             unnamed
# ..         ...    ...                 ...
# 50          50     50  Beneath The Cheeks
# 51          51     51            Rib Cage
# 52          52     52    Front And Center
# 53          53     53   Not The Backboard
# 54          54     54      Good Dirty Fun
#
#                                              Location  \
# 0   Southfield > Sourland Mountain Preserve > * bo...
# 1   Southfield > Sourland Mountain Preserve > * bo...
# 2   Southfield > Sourland Mountain Preserve > * bo...
# 3   Southfield > Sourland Mountain Preserve > * bo...
# 4   Southfield > Sourland Mountain Preserve > * bo...
# ..                                                ...
# 50              Lower Tier > Rockford Park > Delaware
# 51          Rockwood Park / Greenway Trail > Delaware
# 52  Front and Center Boulder > Brandywine Park > D...
# 53  Front and Center Boulder > Brandywine Park > D...
# 54  Front and Center Boulder > Brandywine Park > D...
#
#                                                   URL  Avg Stars  Your Stars  \
# 0   https://www.mountainproject.com/route/11178633...        2.7          -1
# 1   https://www.mountainproject.com/route/11178636...        1.4          -1
# 2   https://www.mountainproject.com/route/11178638...        1.6          -1
# 3   https://www.mountainproject.com/route/11796064...        1.7          -1
# 4   https://www.mountainproject.com/route/11133249...        1.0          -1
# ..                                                ...        ...         ...
# 50  https://www.mountainproject.com/route/12072811...        3.0          -1
# 51  https://www.mountainproject.com/route/11894051...        2.0          -1
# 52  https://www.mountainproject.com/route/12081417...        2.5          -1
# 53  https://www.mountainproject.com/route/12081421...        3.0          -1
# 54  https://www.mountainproject.com/route/12081419...        3.0          -1
#
#    Route Type     Rating  Pitches  Length  Area Latitude  Area Longitude  \
# 0     Boulder    V0 PG13        1     NaN       40.47547       -74.70160
# 1     Boulder         V0        1     NaN       40.47547       -74.70160
# 2     Boulder         V0        1     NaN       40.47547       -74.70160
# 3     Boulder         V0        1     NaN       40.47547       -74.70160
# 4     Boulder        V0+        1     NaN       40.47547       -74.70160
# ..        ...        ...      ...     ...            ...             ...
# 50    Boulder       V3-4        1    12.0       39.76853       -75.57480
# 51    Boulder  V0-1 PG13        2     8.0       39.77404       -75.51579
# 52    Boulder         V1        1    10.0       39.75675       -75.55106
# 53    Boulder         V1        1     8.0       39.75675       -75.55106
# 54    Boulder         V2        1    10.0       39.75675       -75.55106
#
#             Route name                                        Description  \
# 0           Polar Bear                                      Not available
# 1                  Axe                                      Not available
# 2             Lazy Day                                      Not available
# 3              Hatchet  Same SDS as Axe to the right of the arête. Mak...
# 4              Unnamed                                      Not available
# ..                 ...                                                ...
# 50  Beneath The Cheeks  A very low sit start to either Flex-a-flake or...
# 51            Rib Cage  The crux is the middle of the face, the crack ...
# 52    Front And Center  Start in the very venter of the boulder with h...
# 53   Not The Backboard  Sit Start with hands on the good blocky ledge....
# 54      Good Dirty Fun  Sit start hanging on the good blocky edge belo...
#
#    State
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 50   NaN
# 51   NaN
# 52   NaN
# 53   NaN
# 54   NaN
#
# [685 rows x 16 columns]

# %%
combined_chart.Location[1]
# Out:
# 1    Southfield > Sourland Mountain Preserve > * bo...
# 1    Tanaka's Bly Tower > Atlantic City > e. South ...
# 1    b. Practice Face > Ralph Stover State Park (Hi...
# 1    Main Roped Climbing Wall > Alapocas Run State ...
# Name: Location, dtype: object

# %%
combined_chart.Location.str.split(' > ').apply(len).value_counts().sort_index()
# Out:
# 2      1
# 3     90
# 4    124
# 5    399
# 6     71
# Name: Location, dtype: int64

# %%
location_df = combined_chart.Location.apply(lambda x: pd.Series(x.split(' > ')[::-1]))
location_df
# Out:
#              0                               1                          2  \
# 0   New Jersey                    d. Mid-state  * bouldering mid-state NJ
# 1   New Jersey                    d. Mid-state  * bouldering mid-state NJ
# 2   New Jersey                    d. Mid-state  * bouldering mid-state NJ
# 3   New Jersey                    d. Mid-state  * bouldering mid-state NJ
# 4   New Jersey                    d. Mid-state  * bouldering mid-state NJ
# ..         ...                             ...                        ...
# 50    Delaware                   Rockford Park                 Lower Tier
# 51    Delaware  Rockwood Park / Greenway Trail                        NaN
# 52    Delaware                 Brandywine Park   Front and Center Boulder
# 53    Delaware                 Brandywine Park   Front and Center Boulder
# 54    Delaware                 Brandywine Park   Front and Center Boulder
#
#                              3           4    5
# 0   Sourland Mountain Preserve  Southfield  NaN
# 1   Sourland Mountain Preserve  Southfield  NaN
# 2   Sourland Mountain Preserve  Southfield  NaN
# 3   Sourland Mountain Preserve  Southfield  NaN
# 4   Sourland Mountain Preserve  Southfield  NaN
# ..                         ...         ...  ...
# 50                         NaN         NaN  NaN
# 51                         NaN         NaN  NaN
# 52                         NaN         NaN  NaN
# 53                         NaN         NaN  NaN
# 54                         NaN         NaN  NaN
#
# [685 rows x 6 columns]

# %%
combined_chart = combined_chart.drop(columns='Location')
combined_chart['State'] = location_df[0]
combined_chart['Gorge'] = location_df[1]
combined_chart['Area'] = location_df[2]
combined_chart['Crag'] = location_df[3]
combined_chart['Subcrag'] = location_df[4]
combined_chart.head()
# Out:
#    Unnamed: 0  index       Route  \
# 0           0      0  Polar Bear
# 1           1      1         Axe
# 2           2      2    Lazy Day
# 3           3      3     Hatchet
# 4           4      4     unnamed
#
#                                                  URL  Avg Stars  Your Stars  \
# 0  https://www.mountainproject.com/route/11178633...        2.7          -1
# 1  https://www.mountainproject.com/route/11178636...        1.4          -1
# 2  https://www.mountainproject.com/route/11178638...        1.6          -1
# 3  https://www.mountainproject.com/route/11796064...        1.7          -1
# 4  https://www.mountainproject.com/route/11133249...        1.0          -1
#
#   Route Type   Rating  Pitches  Length  Area Latitude  Area Longitude  \
# 0    Boulder  V0 PG13        1     NaN       40.47547        -74.7016
# 1    Boulder       V0        1     NaN       40.47547        -74.7016
# 2    Boulder       V0        1     NaN       40.47547        -74.7016
# 3    Boulder       V0        1     NaN       40.47547        -74.7016
# 4    Boulder      V0+        1     NaN       40.47547        -74.7016
#
#    Route name                                        Description       State  \
# 0  Polar Bear                                      Not available  New Jersey
# 1         Axe                                      Not available  New Jersey
# 2    Lazy Day                                      Not available  New Jersey
# 3     Hatchet  Same SDS as Axe to the right of the arête. Mak...  New Jersey
# 4     Unnamed                                      Not available  New Jersey
#
#           Gorge                       Area                        Crag  \
# 0  d. Mid-state  * bouldering mid-state NJ  Sourland Mountain Preserve
# 1  d. Mid-state  * bouldering mid-state NJ  Sourland Mountain Preserve
# 2  d. Mid-state  * bouldering mid-state NJ  Sourland Mountain Preserve
# 3  d. Mid-state  * bouldering mid-state NJ  Sourland Mountain Preserve
# 4  d. Mid-state  * bouldering mid-state NJ  Sourland Mountain Preserve
#
#       Subcrag
# 0  Southfield
# 1  Southfield
# 2  Southfield
# 3  Southfield
# 4  Southfield

# %%
combined_chart.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Route', 'URL', 'Avg Stars', 'Your Stars',
#        'Route Type', 'Rating', 'Pitches', 'Length', 'Area Latitude',
#        'Area Longitude', 'Route name', 'Description', 'State', 'Gorge', 'Area',
#        'Crag', 'Subcrag'],
#       dtype='object')

# %%
columns_dropped = ['Avg Stars', 'Your Stars',
       'Pitches', 'Length','Unnamed: 0', 'index','Route name']
combined_chart = combined_chart.drop(columns_dropped, axis=1)
combined_chart
# Out:
#                  Route                                                URL  \
# 0           Polar Bear  https://www.mountainproject.com/route/11178633...
# 1                  Axe  https://www.mountainproject.com/route/11178636...
# 2             Lazy Day  https://www.mountainproject.com/route/11178638...
# 3              Hatchet  https://www.mountainproject.com/route/11796064...
# 4              unnamed  https://www.mountainproject.com/route/11133249...
# ..                 ...                                                ...
# 50  Beneath The Cheeks  https://www.mountainproject.com/route/12072811...
# 51            Rib Cage  https://www.mountainproject.com/route/11894051...
# 52    Front And Center  https://www.mountainproject.com/route/12081417...
# 53   Not The Backboard  https://www.mountainproject.com/route/12081421...
# 54      Good Dirty Fun  https://www.mountainproject.com/route/12081419...
#
#    Route Type     Rating  Area Latitude  Area Longitude  \
# 0     Boulder    V0 PG13       40.47547       -74.70160
# 1     Boulder         V0       40.47547       -74.70160
# 2     Boulder         V0       40.47547       -74.70160
# 3     Boulder         V0       40.47547       -74.70160
# 4     Boulder        V0+       40.47547       -74.70160
# ..        ...        ...            ...             ...
# 50    Boulder       V3-4       39.76853       -75.57480
# 51    Boulder  V0-1 PG13       39.77404       -75.51579
# 52    Boulder         V1       39.75675       -75.55106
# 53    Boulder         V1       39.75675       -75.55106
# 54    Boulder         V2       39.75675       -75.55106
#
#                                           Description       State  \
# 0                                       Not available  New Jersey
# 1                                       Not available  New Jersey
# 2                                       Not available  New Jersey
# 3   Same SDS as Axe to the right of the arête. Mak...  New Jersey
# 4                                       Not available  New Jersey
# ..                                                ...         ...
# 50  A very low sit start to either Flex-a-flake or...    Delaware
# 51  The crux is the middle of the face, the crack ...    Delaware
# 52  Start in the very venter of the boulder with h...    Delaware
# 53  Sit Start with hands on the good blocky ledge....    Delaware
# 54  Sit start hanging on the good blocky edge belo...    Delaware
#
#                              Gorge                       Area  \
# 0                     d. Mid-state  * bouldering mid-state NJ
# 1                     d. Mid-state  * bouldering mid-state NJ
# 2                     d. Mid-state  * bouldering mid-state NJ
# 3                     d. Mid-state  * bouldering mid-state NJ
# 4                     d. Mid-state  * bouldering mid-state NJ
# ..                             ...                        ...
# 50                   Rockford Park                 Lower Tier
# 51  Rockwood Park / Greenway Trail                        NaN
# 52                 Brandywine Park   Front and Center Boulder
# 53                 Brandywine Park   Front and Center Boulder
# 54                 Brandywine Park   Front and Center Boulder
#
#                           Crag     Subcrag
# 0   Sourland Mountain Preserve  Southfield
# 1   Sourland Mountain Preserve  Southfield
# 2   Sourland Mountain Preserve  Southfield
# 3   Sourland Mountain Preserve  Southfield
# 4   Sourland Mountain Preserve  Southfield
# ..                         ...         ...
# 50                         NaN         NaN
# 51                         NaN         NaN
# 52                         NaN         NaN
# 53                         NaN         NaN
# 54                         NaN         NaN
#
# [685 rows x 12 columns]

# %%
combined_chart[combined_chart['Gorge'].values=='d. Mid-state']
# Out:
#                  Route                                                URL  \
# 0           Polar Bear  https://www.mountainproject.com/route/11178633...
# 1                  Axe  https://www.mountainproject.com/route/11178636...
# 2             Lazy Day  https://www.mountainproject.com/route/11178638...
# 3              Hatchet  https://www.mountainproject.com/route/11796064...
# 4              unnamed  https://www.mountainproject.com/route/11133249...
# ..                 ...                                                ...
# 84          Misbehavin  https://www.mountainproject.com/route/11886960...
# 85  Richard’s traverse  https://www.mountainproject.com/route/12227024...
# 86  Richard Green Blue  https://www.mountainproject.com/route/12227190...
# 87     Richard’s Crack  https://www.mountainproject.com/route/12227022...
# 88       Rainbow Crack  https://www.mountainproject.com/route/12227024...
#
#    Route Type   Rating  Area Latitude  Area Longitude  \
# 0     Boulder  V0 PG13       40.47547       -74.70160
# 1     Boulder       V0       40.47547       -74.70160
# 2     Boulder       V0       40.47547       -74.70160
# 3     Boulder       V0       40.47547       -74.70160
# 4     Boulder      V0+       40.47547       -74.70160
# ..        ...      ...            ...             ...
# 84    Boulder      V1+       39.83335       -73.45905
# 85    Boulder       V0       40.38636       -74.22764
# 86    Boulder     V3-4       40.38636       -74.22764
# 87    Boulder     V4-5       40.38636       -74.22764
# 88    Boulder     V5-6       40.38636       -74.22764
#
#                                           Description       State  \
# 0                                       Not available  New Jersey
# 1                                       Not available  New Jersey
# 2                                       Not available  New Jersey
# 3   Same SDS as Axe to the right of the arête. Mak...  New Jersey
# 4                                       Not available  New Jersey
# ..                                                ...         ...
# 84                                      5 or so moves  New Jersey
# 85  Very easy, watch out for a small vine hanging ...  New Jersey
# 86  It starts in the middle of the pillar, it is j...  New Jersey
# 87  On the opposite side of rainbow crack, it star...  New Jersey
# 88  Pretty sharp edges, and a small crux on the pi...  New Jersey
#
#            Gorge                       Area                        Crag  \
# 0   d. Mid-state  * bouldering mid-state NJ  Sourland Mountain Preserve
# 1   d. Mid-state  * bouldering mid-state NJ  Sourland Mountain Preserve
# 2   d. Mid-state  * bouldering mid-state NJ  Sourland Mountain Preserve
# 3   d. Mid-state  * bouldering mid-state NJ  Sourland Mountain Preserve
# 4   d. Mid-state  * bouldering mid-state NJ  Sourland Mountain Preserve
# ..           ...                        ...                         ...
# 84  d. Mid-state  * bouldering mid-state NJ      Desperation Buildering
# 85  d. Mid-state  * bouldering mid-state NJ        Watergate bouldering
# 86  d. Mid-state  * bouldering mid-state NJ        Watergate bouldering
# 87  d. Mid-state  * bouldering mid-state NJ        Watergate bouldering
# 88  d. Mid-state  * bouldering mid-state NJ        Watergate bouldering
#
#        Subcrag
# 0   Southfield
# 1   Southfield
# 2   Southfield
# 3   Southfield
# 4   Southfield
# ..         ...
# 84  Spark Wall
# 85         NaN
# 86         NaN
# 87         NaN
# 88         NaN
#
# [89 rows x 12 columns]

# %%
combined_chart['Gorge'] = combined_chart['Gorge'].str.replace('d. Mid-state','Mid-state')
combined_chart
# Out:
# /var/folders/b8/qw7xf4r16w383xrhw3980l4w0000gp/T/ipykernel_14194/1396476170.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   combined_chart['Gorge'] = combined_chart['Gorge'].str.replace('d. Mid-state','Mid-state')
#                  Route                                                URL  \
# 0           Polar Bear  https://www.mountainproject.com/route/11178633...
# 1                  Axe  https://www.mountainproject.com/route/11178636...
# 2             Lazy Day  https://www.mountainproject.com/route/11178638...
# 3              Hatchet  https://www.mountainproject.com/route/11796064...
# 4              unnamed  https://www.mountainproject.com/route/11133249...
# ..                 ...                                                ...
# 50  Beneath The Cheeks  https://www.mountainproject.com/route/12072811...
# 51            Rib Cage  https://www.mountainproject.com/route/11894051...
# 52    Front And Center  https://www.mountainproject.com/route/12081417...
# 53   Not The Backboard  https://www.mountainproject.com/route/12081421...
# 54      Good Dirty Fun  https://www.mountainproject.com/route/12081419...
#
#    Route Type     Rating  Area Latitude  Area Longitude  \
# 0     Boulder    V0 PG13       40.47547       -74.70160
# 1     Boulder         V0       40.47547       -74.70160
# 2     Boulder         V0       40.47547       -74.70160
# 3     Boulder         V0       40.47547       -74.70160
# 4     Boulder        V0+       40.47547       -74.70160
# ..        ...        ...            ...             ...
# 50    Boulder       V3-4       39.76853       -75.57480
# 51    Boulder  V0-1 PG13       39.77404       -75.51579
# 52    Boulder         V1       39.75675       -75.55106
# 53    Boulder         V1       39.75675       -75.55106
# 54    Boulder         V2       39.75675       -75.55106
#
#                                           Description       State  \
# 0                                       Not available  New Jersey
# 1                                       Not available  New Jersey
# 2                                       Not available  New Jersey
# 3   Same SDS as Axe to the right of the arête. Mak...  New Jersey
# 4                                       Not available  New Jersey
# ..                                                ...         ...
# 50  A very low sit start to either Flex-a-flake or...    Delaware
# 51  The crux is the middle of the face, the crack ...    Delaware
# 52  Start in the very venter of the boulder with h...    Delaware
# 53  Sit Start with hands on the good blocky ledge....    Delaware
# 54  Sit start hanging on the good blocky edge belo...    Delaware
#
#                              Gorge                       Area  \
# 0                        Mid-state  * bouldering mid-state NJ
# 1                        Mid-state  * bouldering mid-state NJ
# 2                        Mid-state  * bouldering mid-state NJ
# 3                        Mid-state  * bouldering mid-state NJ
# 4                        Mid-state  * bouldering mid-state NJ
# ..                             ...                        ...
# 50                   Rockford Park                 Lower Tier
# 51  Rockwood Park / Greenway Trail                        NaN
# 52                 Brandywine Park   Front and Center Boulder
# 53                 Brandywine Park   Front and Center Boulder
# 54                 Brandywine Park   Front and Center Boulder
#
#                           Crag     Subcrag
# 0   Sourland Mountain Preserve  Southfield
# 1   Sourland Mountain Preserve  Southfield
# 2   Sourland Mountain Preserve  Southfield
# 3   Sourland Mountain Preserve  Southfield
# 4   Sourland Mountain Preserve  Southfield
# ..                         ...         ...
# 50                         NaN         NaN
# 51                         NaN         NaN
# 52                         NaN         NaN
# 53                         NaN         NaN
# 54                         NaN         NaN
#
# [685 rows x 12 columns]

# %%
combined_chart.isnull()
# Out:
#     Route    URL  Route Type  Rating  Area Latitude  Area Longitude  \
# 0   False  False       False   False          False           False
# 1   False  False       False   False          False           False
# 2   False  False       False   False          False           False
# 3   False  False       False   False          False           False
# 4   False  False       False   False          False           False
# ..    ...    ...         ...     ...            ...             ...
# 50  False  False       False   False          False           False
# 51  False  False       False   False          False           False
# 52  False  False       False   False          False           False
# 53  False  False       False   False          False           False
# 54  False  False       False   False          False           False
#
#     Description  State  Gorge   Area   Crag  Subcrag
# 0         False  False  False  False  False    False
# 1         False  False  False  False  False    False
# 2         False  False  False  False  False    False
# 3         False  False  False  False  False    False
# 4         False  False  False  False  False    False
# ..          ...    ...    ...    ...    ...      ...
# 50        False  False  False  False   True     True
# 51        False  False  False   True   True     True
# 52        False  False  False  False   True     True
# 53        False  False  False  False   True     True
# 54        False  False  False  False   True     True
#
# [685 rows x 12 columns]

# %%
combined_chart = combined_chart.fillna('N/A')
combined_chart
# Out:
#                  Route                                                URL  \
# 0           Polar Bear  https://www.mountainproject.com/route/11178633...
# 1                  Axe  https://www.mountainproject.com/route/11178636...
# 2             Lazy Day  https://www.mountainproject.com/route/11178638...
# 3              Hatchet  https://www.mountainproject.com/route/11796064...
# 4              unnamed  https://www.mountainproject.com/route/11133249...
# ..                 ...                                                ...
# 50  Beneath The Cheeks  https://www.mountainproject.com/route/12072811...
# 51            Rib Cage  https://www.mountainproject.com/route/11894051...
# 52    Front And Center  https://www.mountainproject.com/route/12081417...
# 53   Not The Backboard  https://www.mountainproject.com/route/12081421...
# 54      Good Dirty Fun  https://www.mountainproject.com/route/12081419...
#
#    Route Type     Rating  Area Latitude  Area Longitude  \
# 0     Boulder    V0 PG13       40.47547       -74.70160
# 1     Boulder         V0       40.47547       -74.70160
# 2     Boulder         V0       40.47547       -74.70160
# 3     Boulder         V0       40.47547       -74.70160
# 4     Boulder        V0+       40.47547       -74.70160
# ..        ...        ...            ...             ...
# 50    Boulder       V3-4       39.76853       -75.57480
# 51    Boulder  V0-1 PG13       39.77404       -75.51579
# 52    Boulder         V1       39.75675       -75.55106
# 53    Boulder         V1       39.75675       -75.55106
# 54    Boulder         V2       39.75675       -75.55106
#
#                                           Description       State  \
# 0                                       Not available  New Jersey
# 1                                       Not available  New Jersey
# 2                                       Not available  New Jersey
# 3   Same SDS as Axe to the right of the arête. Mak...  New Jersey
# 4                                       Not available  New Jersey
# ..                                                ...         ...
# 50  A very low sit start to either Flex-a-flake or...    Delaware
# 51  The crux is the middle of the face, the crack ...    Delaware
# 52  Start in the very venter of the boulder with h...    Delaware
# 53  Sit Start with hands on the good blocky ledge....    Delaware
# 54  Sit start hanging on the good blocky edge belo...    Delaware
#
#                              Gorge                       Area  \
# 0                        Mid-state  * bouldering mid-state NJ
# 1                        Mid-state  * bouldering mid-state NJ
# 2                        Mid-state  * bouldering mid-state NJ
# 3                        Mid-state  * bouldering mid-state NJ
# 4                        Mid-state  * bouldering mid-state NJ
# ..                             ...                        ...
# 50                   Rockford Park                 Lower Tier
# 51  Rockwood Park / Greenway Trail                        N/A
# 52                 Brandywine Park   Front and Center Boulder
# 53                 Brandywine Park   Front and Center Boulder
# 54                 Brandywine Park   Front and Center Boulder
#
#                           Crag     Subcrag
# 0   Sourland Mountain Preserve  Southfield
# 1   Sourland Mountain Preserve  Southfield
# 2   Sourland Mountain Preserve  Southfield
# 3   Sourland Mountain Preserve  Southfield
# 4   Sourland Mountain Preserve  Southfield
# ..                         ...         ...
# 50                         N/A         N/A
# 51                         N/A         N/A
# 52                         N/A         N/A
# 53                         N/A         N/A
# 54                         N/A         N/A
#
# [685 rows x 12 columns]

# %%
combined_chart[combined_chart['Area'].values=='* bouldering mid-state NJ']
# Out:
#                  Route                                                URL  \
# 0           Polar Bear  https://www.mountainproject.com/route/11178633...
# 1                  Axe  https://www.mountainproject.com/route/11178636...
# 2             Lazy Day  https://www.mountainproject.com/route/11178638...
# 3              Hatchet  https://www.mountainproject.com/route/11796064...
# 4              unnamed  https://www.mountainproject.com/route/11133249...
# ..                 ...                                                ...
# 84          Misbehavin  https://www.mountainproject.com/route/11886960...
# 85  Richard’s traverse  https://www.mountainproject.com/route/12227024...
# 86  Richard Green Blue  https://www.mountainproject.com/route/12227190...
# 87     Richard’s Crack  https://www.mountainproject.com/route/12227022...
# 88       Rainbow Crack  https://www.mountainproject.com/route/12227024...
#
#    Route Type   Rating  Area Latitude  Area Longitude  \
# 0     Boulder  V0 PG13       40.47547       -74.70160
# 1     Boulder       V0       40.47547       -74.70160
# 2     Boulder       V0       40.47547       -74.70160
# 3     Boulder       V0       40.47547       -74.70160
# 4     Boulder      V0+       40.47547       -74.70160
# ..        ...      ...            ...             ...
# 84    Boulder      V1+       39.83335       -73.45905
# 85    Boulder       V0       40.38636       -74.22764
# 86    Boulder     V3-4       40.38636       -74.22764
# 87    Boulder     V4-5       40.38636       -74.22764
# 88    Boulder     V5-6       40.38636       -74.22764
#
#                                           Description       State      Gorge  \
# 0                                       Not available  New Jersey  Mid-state
# 1                                       Not available  New Jersey  Mid-state
# 2                                       Not available  New Jersey  Mid-state
# 3   Same SDS as Axe to the right of the arête. Mak...  New Jersey  Mid-state
# 4                                       Not available  New Jersey  Mid-state
# ..                                                ...         ...        ...
# 84                                      5 or so moves  New Jersey  Mid-state
# 85  Very easy, watch out for a small vine hanging ...  New Jersey  Mid-state
# 86  It starts in the middle of the pillar, it is j...  New Jersey  Mid-state
# 87  On the opposite side of rainbow crack, it star...  New Jersey  Mid-state
# 88  Pretty sharp edges, and a small crux on the pi...  New Jersey  Mid-state
#
#                          Area                        Crag     Subcrag
# 0   * bouldering mid-state NJ  Sourland Mountain Preserve  Southfield
# 1   * bouldering mid-state NJ  Sourland Mountain Preserve  Southfield
# 2   * bouldering mid-state NJ  Sourland Mountain Preserve  Southfield
# 3   * bouldering mid-state NJ  Sourland Mountain Preserve  Southfield
# 4   * bouldering mid-state NJ  Sourland Mountain Preserve  Southfield
# ..                        ...                         ...         ...
# 84  * bouldering mid-state NJ      Desperation Buildering  Spark Wall
# 85  * bouldering mid-state NJ        Watergate bouldering         N/A
# 86  * bouldering mid-state NJ        Watergate bouldering         N/A
# 87  * bouldering mid-state NJ        Watergate bouldering         N/A
# 88  * bouldering mid-state NJ        Watergate bouldering         N/A
#
# [89 rows x 12 columns]

# %%
combined_chart['Area'] = combined_chart['Area'].str.replace('*','')
combined_chart['Area'] = combined_chart['Area'].str.lstrip().str.title()
combined_chart
# Out:
# /var/folders/b8/qw7xf4r16w383xrhw3980l4w0000gp/T/ipykernel_14194/2751421699.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   combined_chart['Area'] = combined_chart['Area'].str.replace('*','')
#                  Route                                                URL  \
# 0           Polar Bear  https://www.mountainproject.com/route/11178633...
# 1                  Axe  https://www.mountainproject.com/route/11178636...
# 2             Lazy Day  https://www.mountainproject.com/route/11178638...
# 3              Hatchet  https://www.mountainproject.com/route/11796064...
# 4              unnamed  https://www.mountainproject.com/route/11133249...
# ..                 ...                                                ...
# 50  Beneath The Cheeks  https://www.mountainproject.com/route/12072811...
# 51            Rib Cage  https://www.mountainproject.com/route/11894051...
# 52    Front And Center  https://www.mountainproject.com/route/12081417...
# 53   Not The Backboard  https://www.mountainproject.com/route/12081421...
# 54      Good Dirty Fun  https://www.mountainproject.com/route/12081419...
#
#    Route Type     Rating  Area Latitude  Area Longitude  \
# 0     Boulder    V0 PG13       40.47547       -74.70160
# 1     Boulder         V0       40.47547       -74.70160
# 2     Boulder         V0       40.47547       -74.70160
# 3     Boulder         V0       40.47547       -74.70160
# 4     Boulder        V0+       40.47547       -74.70160
# ..        ...        ...            ...             ...
# 50    Boulder       V3-4       39.76853       -75.57480
# 51    Boulder  V0-1 PG13       39.77404       -75.51579
# 52    Boulder         V1       39.75675       -75.55106
# 53    Boulder         V1       39.75675       -75.55106
# 54    Boulder         V2       39.75675       -75.55106
#
#                                           Description       State  \
# 0                                       Not available  New Jersey
# 1                                       Not available  New Jersey
# 2                                       Not available  New Jersey
# 3   Same SDS as Axe to the right of the arête. Mak...  New Jersey
# 4                                       Not available  New Jersey
# ..                                                ...         ...
# 50  A very low sit start to either Flex-a-flake or...    Delaware
# 51  The crux is the middle of the face, the crack ...    Delaware
# 52  Start in the very venter of the boulder with h...    Delaware
# 53  Sit Start with hands on the good blocky ledge....    Delaware
# 54  Sit start hanging on the good blocky edge belo...    Delaware
#
#                              Gorge                      Area  \
# 0                        Mid-state   Bouldering Mid-State Nj
# 1                        Mid-state   Bouldering Mid-State Nj
# 2                        Mid-state   Bouldering Mid-State Nj
# 3                        Mid-state   Bouldering Mid-State Nj
# 4                        Mid-state   Bouldering Mid-State Nj
# ..                             ...                       ...
# 50                   Rockford Park                Lower Tier
# 51  Rockwood Park / Greenway Trail                       N/A
# 52                 Brandywine Park  Front And Center Boulder
# 53                 Brandywine Park  Front And Center Boulder
# 54                 Brandywine Park  Front And Center Boulder
#
#                           Crag     Subcrag
# 0   Sourland Mountain Preserve  Southfield
# 1   Sourland Mountain Preserve  Southfield
# 2   Sourland Mountain Preserve  Southfield
# 3   Sourland Mountain Preserve  Southfield
# 4   Sourland Mountain Preserve  Southfield
# ..                         ...         ...
# 50                         N/A         N/A
# 51                         N/A         N/A
# 52                         N/A         N/A
# 53                         N/A         N/A
# 54                         N/A         N/A
#
# [685 rows x 12 columns]

# %%
combined_chart['Area'].value_counts()
# Out:
# Haycock Mountain (Nockamixon)           240
# Philly                                  193
# Bouldering Mid-State Nj                  89
# East Branch Brandywine Creek             28
# Hay Creek Boulders                       17
# Crum Woods                               17
# Smedley Park                             15
# Spearhead Boulder                        12
# Lower Tier                               10
# Scattered Small Boulders                  7
# Downingtown Boulders                      7
# Spacklehead Boulder                       7
# Heat Index Boulders                       6
# Ralph Stover State Park (High Rocks)      5
# Ridley Creek Boulders                     4
# The Falls                                 4
# Black Widow Boulder                       4
# Saul Preserve                             3
# Main Roped Climbing Wall                  3
# Saint Peter'S Village                     3
# Front And Center Boulder                  3
# Atlantic City                             2
# Makeout Cave Cluster                      2
# Chester Valley Trail Outcrop              2
# Tyler Park Bouldering                     1
# N/A                                       1
# Name: Area, dtype: int64

# %%
combined_chart['Gorge'].value_counts()
# Out:
# Southeastern Lowlands             539
# Mid-state                          89
# Rockford Park                      48
# Alapocas Run State Park             3
# Brandywine Park                     3
# e. South                            2
# Rockwood Park / Greenway Trail      1
# Name: Gorge, dtype: int64

# %%
combined_chart['State'].value_counts()
# Out:
# Pennsylvania    539
# New Jersey       91
# Delaware         55
# Name: State, dtype: int64

# %%
combined_chart['Rating'].values
# Out:
# array(['V0 PG13', 'V0', 'V0', 'V0', 'V0+', 'V1', 'V2-3', 'V3+ PG13', 'V0',
#        'V0', 'V1', 'V1', 'V1-2', 'V2', 'V2', 'V2', 'V2', 'V3', 'V3', 'V3',
#        'V3', 'V3+', 'V4+', 'V5', 'V0', 'V0', 'V0 PG13', 'V1', 'V1', 'V1+',
#        'V4', 'V5-6', 'V6', 'V0', 'V2', 'V2 X', 'V3 PG13', 'V3+', 'V5',
#        'V6', 'V6-7', 'V8', 'V8+ PG13', 'V1', 'V3', 'V4-5', 'V5-', 'V9',
#        'V0', 'V1', 'V1', 'V2', 'V2', 'V2', 'V3', 'V0', 'V5', 'V8', 'V8',
#        'V0', 'V0', 'V0', 'V0', 'V0', 'V0', 'V1', 'V1', 'V1', 'V1', 'V1',
#        'V1-2', 'V2', 'V2', 'V2', 'V2', 'V2-3', 'V3', 'V3', 'V4', 'V5',
#        'V6-7', 'V7', 'V1', 'V1+', 'V1+', 'V0', 'V3-4', 'V4-5', 'V5-6',
#        'V0+', 'V2', 'V0+ R', 'V0', 'V0+', 'V0+', 'V4', 'V0-1', 'V5',
#        'V8-9', 'V2', 'V0', 'V2', 'V4', 'V6', 'V0+', 'V1', 'V3', 'V3',
#        'V5', 'V2-', 'V2', 'V3', 'V4', 'V4', 'V6', 'V7 PG13', 'V9', 'V3',
#        'V0', 'V0', 'V0+', 'V1', 'V2', 'V3', 'V4', 'V9', 'V1', 'V2',
#        'V4 PG13', 'V4', 'V8 PG13', 'V8', 'V0+', 'V1-', 'V1-2', 'V2', 'V0',
#        'V1', 'V0-', 'V0-', 'V1', 'V2', 'V2', 'V7', 'V7', 'V1', 'V1', 'V4',
#        'V4', 'V6', 'V6', 'V0+ PG13', 'V1', 'V2', 'V2 PG13', 'V2 PG13',
#        'V5 PG13', 'V5', 'V5+', 'V6+', 'V7 PG13', 'V8', 'V9 R', 'V10 PG13',
#        'V6', 'V7', 'V1', 'V0', 'V0', 'V2', 'V1 PG13', 'V0', 'V3', 'V3',
#        'V4', 'V8', 'V3+', 'V5-', 'V8', 'V10', 'V1- PG13', 'V5', 'V6',
#        '5.10- V1 WI2- M1-2 C1+ Easy Snow', 'V3', 'V4-', 'V5', 'V0', 'V2',
#        'V5', 'V0', 'V1', 'V2', 'V0', 'V2', 'V2', 'V3', 'V7', 'V8', 'V4',
#        'V1', 'V3', 'V5', 'V5+', 'V5', 'V8', 'V0 PG13', 'V2', 'V2', 'V0',
#        'V6 R', 'V7', 'V0-', 'V0', 'V1', 'V1', 'V0+', 'V1', 'V1', 'V1',
#        'V2', 'V2', 'V3', 'V3', 'V3', 'V4', 'V4', 'V4', 'V4', 'V4-5', 'V6',
#        'V0-', 'V1', 'V4', 'V6', 'V4', 'V5', 'V4', 'V3', 'V5', 'V6', 'V9',
#        'V2-3', 'V0', 'V4', 'V7', 'V10-', 'V7 R', 'V4', 'V3', 'V4', 'V4',
#        'V5', 'V5', 'V6', 'V2', 'V3', 'V3', 'V4', 'V4', 'V2', 'V2', 'V3',
#        'V4', 'V4', 'V5+', 'V5-6', 'V7', 'V0', 'V1', 'V1', 'V2', 'V3',
#        'V5', 'V5', 'V5', 'V0-', 'V0', 'V2', 'V3', 'V0', 'V2', 'V0 PG13',
#        'V4', 'V7', 'V8', 'V6', 'V10', 'V0', 'V3', 'V3', 'V5', 'V6', 'V1+',
#        'V3', 'V4', 'V6', 'V8', 'V11', 'V6', 'V7', 'V8', 'V5 R', 'V6 R',
#        'V4', 'V2', 'V3', 'V7', 'V7', 'V6', 'V2', 'V3', 'V6', 'V5', 'V4',
#        'V5', 'V6', 'V7', 'V8', 'V8', 'V4', 'V6 PG13', 'V11 R', 'V0- PG13',
#        'V0-', 'V4', 'V5', 'V5 PG13', 'V7-8', 'V4', 'V5', 'V6', 'V4', 'V5',
#        'V7', 'V6 R', '5.9 V0-', '5.12 V5+ PG13', 'V1', '5.10c V1', 'V2',
#        'V0', 'V2', 'V3-', 'V3-', 'V8-', 'V0', 'V0', 'V1+', 'V1-2', 'V4',
#        'V5-', 'V6-7', 'V7', 'V8', 'V0', 'V1', 'V0', 'V0+', 'V1', 'V1',
#        'V1-2', 'V2-', 'V2', 'V2', 'V3', 'V3-4', 'V6', 'V7-', 'V0', 'V0',
#        'V1-', 'V0-', 'V1', 'V1', 'V1', 'V2', 'V2 PG13', 'V2', 'V2-3',
#        'V3', 'V3', 'V3+', 'V3+', 'V4', 'V4', 'V5-', 'V1', 'V2+',
#        'V3 PG13', 'V4-', 'V6+', 'V7', 'V0', 'V1', 'V1', 'V2', 'V1+', 'V3',
#        'V3 R', 'V-easy', 'V0-', 'V0', 'V0', 'V0', 'V1', 'V1', 'V1', 'V1+',
#        'V1-2', 'V2', 'V0', 'V1', 'V0', 'V1+', 'V0+', 'V0+', 'V1', 'V1+',
#        'V2', 'V0-', 'V0+', 'V2', 'V1-', 'V4-5', 'V-easy', 'V-easy',
#        'V-easy', 'V-easy', 'V1+', 'V3', 'V0+', 'V0-1', 'V1', 'V-easy',
#        'V-easy', 'V1', 'V1+', 'V2', 'V2+', 'V0+', 'V1+', 'V0-', 'V0',
#        'V0', 'V0', 'V0+', 'V0+', 'V2', 'V2', 'V4-5', 'V1- PG13', 'V0-',
#        'V0-', 'V0', 'V0+', 'V1+', 'V2', 'V0', 'V1', 'V1', 'V0 PG13',
#        'V0-1', 'V2', 'V2 PG13', 'V2+', 'V3', 'V4-5 R', 'V0-', 'V0', 'V0+',
#        'V1- PG13', 'V1', 'V0-', 'V0', 'V0', 'V0-1', 'V1', 'V0', 'V0',
#        'V2', 'V-easy', 'V0-', 'V0', 'V0+', 'V0+', 'V1', 'V2+', 'V3',
#        'V0-', 'V1 PG13', 'V2', 'V0-', 'V0', 'V1', 'V1', 'V3', 'V4-5',
#        'V-easy', 'V4', 'V2 R', 'V0-', 'V1+', 'V2', 'V4', 'V5', 'V0+',
#        'V0', 'V1', 'V2+', 'V3+', 'V0', 'V0+', 'V1', 'V1+', 'V-easy',
#        'V-easy', 'V0', 'V0+', 'V1', 'V1', 'V3', 'V0', 'V1', 'V2', 'V2',
#        'V2', 'V2', 'V4', 'V0-', 'V0', 'V0', 'V0', 'V0-1', 'V2', 'V3',
#        'V0', 'V0-1', 'V0-1', 'V0-1', 'V-easy', 'V-easy', 'V-easy', 'V0-',
#        'V0', 'V0', 'V0', 'V1', 'V3', 'V0', 'V2-3', 'V4', 'V5-', 'V1',
#        'V2', 'V3', 'V2', 'V0', 'V0-1', 'V0-1 PG13', 'V2', 'V2-3', 'V0-',
#        'V1 PG13', 'V1+', 'V2 PG13', 'V3', 'V4 PG13', 'V0', 'V1', 'V1+',
#        'V1+', 'V2-3', 'V0', 'V1', 'V1+', 'V1+', 'V3- PG13', 'V3-', 'V3+',
#        'V0', 'V1', 'V1', 'V2', 'V3', 'V4-5', 'V-easy', 'V0', 'V3-', 'V1',
#        'V0', 'V0-1', 'V1', 'V1-2', 'V0', 'V0', 'V0', 'V0', 'V0', 'V0-1',
#        'V0-1', 'V0-1', 'V1-2', 'V1-2', 'V2-3', 'V2-3', 'V3-4 PG13',
#        'V3-4', 'V4-5', 'V0', 'V0', 'V3-4', 'V0-', 'V0', 'V1-', 'V2', 'V3',
#        'V0+', 'V1+', 'V2', 'V-easy', 'V0', 'V0', 'V0', 'V0', 'V0',
#        'V0-1 R', 'V1-', 'V1-2 R', 'V0 PG13', 'V0+', '5.10d V2',
#        '5.12a V4', 'V0 PG13', 'V0', 'V0 PG13', 'V0', 'V0+', 'V0+', 'V0',
#        'V0 PG13', 'V0-1 R', 'V0-1 R', 'V1', 'V1', 'V2-', 'V3', 'V3+',
#        'V4', 'V4+', 'V5', 'V0', 'V1', 'V2', 'V2+', 'V3', 'V3 PG13', 'V4+',
#        'V-easy', 'V1-', 'V2+', 'V7', 'V0', 'V1', 'V1', 'V1+', 'V2-3',
#        'V3-4', 'V4', 'V0', 'V2', 'V0-', 'V1-', 'V1', 'V1', 'V1', 'V1',
#        'V2', 'V2', 'V2+', 'V3-4', 'V0-1 PG13', 'V1', 'V1', 'V2'],
#       dtype=object)

# %%
combined_chart['Rating'] = combined_chart['Rating'].str.replace('PG13','')
combined_chart['Rating'] = combined_chart['Rating'].str.replace('R','')
combined_chart['Rating'] = combined_chart['Rating'].str.replace('V-easy','V0-1')
combined_chart['Rating'] = combined_chart['Rating'].str.replace(".*(?=V)", '', regex=True)

# %%
combined_chart['Rating'].values
# Out:
# array(['V0 ', 'V0', 'V0', 'V0', 'V0+', 'V1', 'V2-3', 'V3+ ', 'V0', 'V0',
#        'V1', 'V1', 'V1-2', 'V2', 'V2', 'V2', 'V2', 'V3', 'V3', 'V3', 'V3',
#        'V3+', 'V4+', 'V5', 'V0', 'V0', 'V0 ', 'V1', 'V1', 'V1+', 'V4',
#        'V5-6', 'V6', 'V0', 'V2', 'V2 X', 'V3 ', 'V3+', 'V5', 'V6', 'V6-7',
#        'V8', 'V8+ ', 'V1', 'V3', 'V4-5', 'V5-', 'V9', 'V0', 'V1', 'V1',
#        'V2', 'V2', 'V2', 'V3', 'V0', 'V5', 'V8', 'V8', 'V0', 'V0', 'V0',
#        'V0', 'V0', 'V0', 'V1', 'V1', 'V1', 'V1', 'V1', 'V1-2', 'V2', 'V2',
#        'V2', 'V2', 'V2-3', 'V3', 'V3', 'V4', 'V5', 'V6-7', 'V7', 'V1',
#        'V1+', 'V1+', 'V0', 'V3-4', 'V4-5', 'V5-6', 'V0+', 'V2', 'V0+ ',
#        'V0', 'V0+', 'V0+', 'V4', 'V0-1', 'V5', 'V8-9', 'V2', 'V0', 'V2',
#        'V4', 'V6', 'V0+', 'V1', 'V3', 'V3', 'V5', 'V2-', 'V2', 'V3', 'V4',
#        'V4', 'V6', 'V7 ', 'V9', 'V3', 'V0', 'V0', 'V0+', 'V1', 'V2', 'V3',
#        'V4', 'V9', 'V1', 'V2', 'V4 ', 'V4', 'V8 ', 'V8', 'V0+', 'V1-',
#        'V1-2', 'V2', 'V0', 'V1', 'V0-', 'V0-', 'V1', 'V2', 'V2', 'V7',
#        'V7', 'V1', 'V1', 'V4', 'V4', 'V6', 'V6', 'V0+ ', 'V1', 'V2',
#        'V2 ', 'V2 ', 'V5 ', 'V5', 'V5+', 'V6+', 'V7 ', 'V8', 'V9 ',
#        'V10 ', 'V6', 'V7', 'V1', 'V0', 'V0', 'V2', 'V1 ', 'V0', 'V3',
#        'V3', 'V4', 'V8', 'V3+', 'V5-', 'V8', 'V10', 'V1- ', 'V5', 'V6',
#        'V1 WI2- M1-2 C1+ Easy Snow', 'V3', 'V4-', 'V5', 'V0', 'V2', 'V5',
#        'V0', 'V1', 'V2', 'V0', 'V2', 'V2', 'V3', 'V7', 'V8', 'V4', 'V1',
#        'V3', 'V5', 'V5+', 'V5', 'V8', 'V0 ', 'V2', 'V2', 'V0', 'V6 ',
#        'V7', 'V0-', 'V0', 'V1', 'V1', 'V0+', 'V1', 'V1', 'V1', 'V2', 'V2',
#        'V3', 'V3', 'V3', 'V4', 'V4', 'V4', 'V4', 'V4-5', 'V6', 'V0-',
#        'V1', 'V4', 'V6', 'V4', 'V5', 'V4', 'V3', 'V5', 'V6', 'V9', 'V2-3',
#        'V0', 'V4', 'V7', 'V10-', 'V7 ', 'V4', 'V3', 'V4', 'V4', 'V5',
#        'V5', 'V6', 'V2', 'V3', 'V3', 'V4', 'V4', 'V2', 'V2', 'V3', 'V4',
#        'V4', 'V5+', 'V5-6', 'V7', 'V0', 'V1', 'V1', 'V2', 'V3', 'V5',
#        'V5', 'V5', 'V0-', 'V0', 'V2', 'V3', 'V0', 'V2', 'V0 ', 'V4', 'V7',
#        'V8', 'V6', 'V10', 'V0', 'V3', 'V3', 'V5', 'V6', 'V1+', 'V3', 'V4',
#        'V6', 'V8', 'V11', 'V6', 'V7', 'V8', 'V5 ', 'V6 ', 'V4', 'V2',
#        'V3', 'V7', 'V7', 'V6', 'V2', 'V3', 'V6', 'V5', 'V4', 'V5', 'V6',
#        'V7', 'V8', 'V8', 'V4', 'V6 ', 'V11 ', 'V0- ', 'V0-', 'V4', 'V5',
#        'V5 ', 'V7-8', 'V4', 'V5', 'V6', 'V4', 'V5', 'V7', 'V6 ', 'V0-',
#        'V5+ ', 'V1', 'V1', 'V2', 'V0', 'V2', 'V3-', 'V3-', 'V8-', 'V0',
#        'V0', 'V1+', 'V1-2', 'V4', 'V5-', 'V6-7', 'V7', 'V8', 'V0', 'V1',
#        'V0', 'V0+', 'V1', 'V1', 'V1-2', 'V2-', 'V2', 'V2', 'V3', 'V3-4',
#        'V6', 'V7-', 'V0', 'V0', 'V1-', 'V0-', 'V1', 'V1', 'V1', 'V2',
#        'V2 ', 'V2', 'V2-3', 'V3', 'V3', 'V3+', 'V3+', 'V4', 'V4', 'V5-',
#        'V1', 'V2+', 'V3 ', 'V4-', 'V6+', 'V7', 'V0', 'V1', 'V1', 'V2',
#        'V1+', 'V3', 'V3 ', 'V0-1', 'V0-', 'V0', 'V0', 'V0', 'V1', 'V1',
#        'V1', 'V1+', 'V1-2', 'V2', 'V0', 'V1', 'V0', 'V1+', 'V0+', 'V0+',
#        'V1', 'V1+', 'V2', 'V0-', 'V0+', 'V2', 'V1-', 'V4-5', 'V0-1',
#        'V0-1', 'V0-1', 'V0-1', 'V1+', 'V3', 'V0+', 'V0-1', 'V1', 'V0-1',
#        'V0-1', 'V1', 'V1+', 'V2', 'V2+', 'V0+', 'V1+', 'V0-', 'V0', 'V0',
#        'V0', 'V0+', 'V0+', 'V2', 'V2', 'V4-5', 'V1- ', 'V0-', 'V0-', 'V0',
#        'V0+', 'V1+', 'V2', 'V0', 'V1', 'V1', 'V0 ', 'V0-1', 'V2', 'V2 ',
#        'V2+', 'V3', 'V4-5 ', 'V0-', 'V0', 'V0+', 'V1- ', 'V1', 'V0-',
#        'V0', 'V0', 'V0-1', 'V1', 'V0', 'V0', 'V2', 'V0-1', 'V0-', 'V0',
#        'V0+', 'V0+', 'V1', 'V2+', 'V3', 'V0-', 'V1 ', 'V2', 'V0-', 'V0',
#        'V1', 'V1', 'V3', 'V4-5', 'V0-1', 'V4', 'V2 ', 'V0-', 'V1+', 'V2',
#        'V4', 'V5', 'V0+', 'V0', 'V1', 'V2+', 'V3+', 'V0', 'V0+', 'V1',
#        'V1+', 'V0-1', 'V0-1', 'V0', 'V0+', 'V1', 'V1', 'V3', 'V0', 'V1',
#        'V2', 'V2', 'V2', 'V2', 'V4', 'V0-', 'V0', 'V0', 'V0', 'V0-1',
#        'V2', 'V3', 'V0', 'V0-1', 'V0-1', 'V0-1', 'V0-1', 'V0-1', 'V0-1',
#        'V0-', 'V0', 'V0', 'V0', 'V1', 'V3', 'V0', 'V2-3', 'V4', 'V5-',
#        'V1', 'V2', 'V3', 'V2', 'V0', 'V0-1', 'V0-1 ', 'V2', 'V2-3', 'V0-',
#        'V1 ', 'V1+', 'V2 ', 'V3', 'V4 ', 'V0', 'V1', 'V1+', 'V1+', 'V2-3',
#        'V0', 'V1', 'V1+', 'V1+', 'V3- ', 'V3-', 'V3+', 'V0', 'V1', 'V1',
#        'V2', 'V3', 'V4-5', 'V0-1', 'V0', 'V3-', 'V1', 'V0', 'V0-1', 'V1',
#        'V1-2', 'V0', 'V0', 'V0', 'V0', 'V0', 'V0-1', 'V0-1', 'V0-1',
#        'V1-2', 'V1-2', 'V2-3', 'V2-3', 'V3-4 ', 'V3-4', 'V4-5', 'V0',
#        'V0', 'V3-4', 'V0-', 'V0', 'V1-', 'V2', 'V3', 'V0+', 'V1+', 'V2',
#        'V0-1', 'V0', 'V0', 'V0', 'V0', 'V0', 'V0-1 ', 'V1-', 'V1-2 ',
#        'V0 ', 'V0+', 'V2', 'V4', 'V0 ', 'V0', 'V0 ', 'V0', 'V0+', 'V0+',
#        'V0', 'V0 ', 'V0-1 ', 'V0-1 ', 'V1', 'V1', 'V2-', 'V3', 'V3+',
#        'V4', 'V4+', 'V5', 'V0', 'V1', 'V2', 'V2+', 'V3', 'V3 ', 'V4+',
#        'V0-1', 'V1-', 'V2+', 'V7', 'V0', 'V1', 'V1', 'V1+', 'V2-3',
#        'V3-4', 'V4', 'V0', 'V2', 'V0-', 'V1-', 'V1', 'V1', 'V1', 'V1',
#        'V2', 'V2', 'V2+', 'V3-4', 'V0-1 ', 'V1', 'V1', 'V2'], dtype=object)

# %%
print(combined_chart[combined_chart['Rating']=='V1 WI2- M1-2 C1+ Easy Snow'].index.values)
# Out:
# [92]

# %%
print(combined_chart['Rating'][92])
# Out:
# V1 WI2- M1-2 C1+ Easy Snow

# %%
combined_chart['Rating'][92] = 'V1'
# Out:
# /var/folders/b8/qw7xf4r16w383xrhw3980l4w0000gp/T/ipykernel_14194/662197244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_chart['Rating'][92] = 'V1'

# %%
combined_chart['Rating'].values
# Out:
# array(['V0 ', 'V0', 'V0', 'V0', 'V0+', 'V1', 'V2-3', 'V3+ ', 'V0', 'V0',
#        'V1', 'V1', 'V1-2', 'V2', 'V2', 'V2', 'V2', 'V3', 'V3', 'V3', 'V3',
#        'V3+', 'V4+', 'V5', 'V0', 'V0', 'V0 ', 'V1', 'V1', 'V1+', 'V4',
#        'V5-6', 'V6', 'V0', 'V2', 'V2 X', 'V3 ', 'V3+', 'V5', 'V6', 'V6-7',
#        'V8', 'V8+ ', 'V1', 'V3', 'V4-5', 'V5-', 'V9', 'V0', 'V1', 'V1',
#        'V2', 'V2', 'V2', 'V3', 'V0', 'V5', 'V8', 'V8', 'V0', 'V0', 'V0',
#        'V0', 'V0', 'V0', 'V1', 'V1', 'V1', 'V1', 'V1', 'V1-2', 'V2', 'V2',
#        'V2', 'V2', 'V2-3', 'V3', 'V3', 'V4', 'V5', 'V6-7', 'V7', 'V1',
#        'V1+', 'V1+', 'V0', 'V3-4', 'V4-5', 'V5-6', 'V0+', 'V2', 'V0+ ',
#        'V0', 'V0+', 'V0+', 'V4', 'V0-1', 'V5', 'V8-9', 'V2', 'V0', 'V2',
#        'V4', 'V6', 'V0+', 'V1', 'V3', 'V3', 'V5', 'V2-', 'V2', 'V3', 'V4',
#        'V4', 'V6', 'V7 ', 'V9', 'V3', 'V0', 'V0', 'V0+', 'V1', 'V2', 'V3',
#        'V4', 'V9', 'V1', 'V2', 'V4 ', 'V4', 'V8 ', 'V8', 'V0+', 'V1-',
#        'V1-2', 'V2', 'V0', 'V1', 'V0-', 'V0-', 'V1', 'V2', 'V2', 'V7',
#        'V7', 'V1', 'V1', 'V4', 'V4', 'V6', 'V6', 'V0+ ', 'V1', 'V2',
#        'V2 ', 'V2 ', 'V5 ', 'V5', 'V5+', 'V6+', 'V7 ', 'V8', 'V9 ',
#        'V10 ', 'V6', 'V7', 'V1', 'V0', 'V0', 'V2', 'V1 ', 'V0', 'V3',
#        'V3', 'V4', 'V8', 'V3+', 'V5-', 'V8', 'V10', 'V1- ', 'V5', 'V6',
#        'V1', 'V3', 'V4-', 'V5', 'V0', 'V2', 'V5', 'V0', 'V1', 'V2', 'V0',
#        'V2', 'V2', 'V3', 'V7', 'V8', 'V4', 'V1', 'V3', 'V5', 'V5+', 'V5',
#        'V8', 'V0 ', 'V2', 'V2', 'V0', 'V6 ', 'V7', 'V0-', 'V0', 'V1',
#        'V1', 'V0+', 'V1', 'V1', 'V1', 'V2', 'V2', 'V3', 'V3', 'V3', 'V4',
#        'V4', 'V4', 'V4', 'V4-5', 'V6', 'V0-', 'V1', 'V4', 'V6', 'V4',
#        'V5', 'V4', 'V3', 'V5', 'V6', 'V9', 'V2-3', 'V0', 'V4', 'V7',
#        'V10-', 'V7 ', 'V4', 'V3', 'V4', 'V4', 'V5', 'V5', 'V6', 'V2',
#        'V3', 'V3', 'V4', 'V4', 'V2', 'V2', 'V3', 'V4', 'V4', 'V5+',
#        'V5-6', 'V7', 'V0', 'V1', 'V1', 'V2', 'V3', 'V5', 'V5', 'V5',
#        'V0-', 'V0', 'V2', 'V3', 'V0', 'V2', 'V0 ', 'V4', 'V7', 'V8', 'V6',
#        'V10', 'V0', 'V3', 'V3', 'V5', 'V6', 'V1+', 'V3', 'V4', 'V6', 'V8',
#        'V11', 'V6', 'V7', 'V8', 'V5 ', 'V6 ', 'V4', 'V2', 'V3', 'V7',
#        'V7', 'V6', 'V2', 'V3', 'V6', 'V5', 'V4', 'V5', 'V6', 'V7', 'V8',
#        'V8', 'V4', 'V6 ', 'V11 ', 'V0- ', 'V0-', 'V4', 'V5', 'V5 ',
#        'V7-8', 'V4', 'V5', 'V6', 'V4', 'V5', 'V7', 'V6 ', 'V0-', 'V5+ ',
#        'V1', 'V1', 'V2', 'V0', 'V2', 'V3-', 'V3-', 'V8-', 'V0', 'V0',
#        'V1+', 'V1-2', 'V4', 'V5-', 'V6-7', 'V7', 'V8', 'V0', 'V1', 'V0',
#        'V0+', 'V1', 'V1', 'V1-2', 'V2-', 'V2', 'V2', 'V3', 'V3-4', 'V6',
#        'V7-', 'V0', 'V0', 'V1-', 'V0-', 'V1', 'V1', 'V1', 'V2', 'V2 ',
#        'V2', 'V2-3', 'V3', 'V3', 'V3+', 'V3+', 'V4', 'V4', 'V5-', 'V1',
#        'V2+', 'V3 ', 'V4-', 'V6+', 'V7', 'V0', 'V1', 'V1', 'V2', 'V1+',
#        'V3', 'V3 ', 'V0-1', 'V0-', 'V0', 'V0', 'V0', 'V1', 'V1', 'V1',
#        'V1+', 'V1-2', 'V2', 'V0', 'V1', 'V0', 'V1+', 'V0+', 'V0+', 'V1',
#        'V1+', 'V2', 'V0-', 'V0+', 'V2', 'V1-', 'V4-5', 'V0-1', 'V0-1',
#        'V0-1', 'V0-1', 'V1+', 'V3', 'V0+', 'V0-1', 'V1', 'V0-1', 'V0-1',
#        'V1', 'V1+', 'V2', 'V2+', 'V0+', 'V1+', 'V0-', 'V0', 'V0', 'V0',
#        'V0+', 'V0+', 'V2', 'V2', 'V4-5', 'V1- ', 'V0-', 'V0-', 'V0',
#        'V0+', 'V1+', 'V2', 'V0', 'V1', 'V1', 'V0 ', 'V0-1', 'V2', 'V2 ',
#        'V2+', 'V3', 'V4-5 ', 'V0-', 'V0', 'V0+', 'V1- ', 'V1', 'V0-',
#        'V0', 'V0', 'V0-1', 'V1', 'V0', 'V0', 'V2', 'V0-1', 'V0-', 'V0',
#        'V0+', 'V0+', 'V1', 'V2+', 'V3', 'V0-', 'V1 ', 'V2', 'V0-', 'V0',
#        'V1', 'V1', 'V3', 'V4-5', 'V0-1', 'V4', 'V2 ', 'V0-', 'V1+', 'V2',
#        'V4', 'V5', 'V0+', 'V0', 'V1', 'V2+', 'V3+', 'V0', 'V0+', 'V1',
#        'V1+', 'V0-1', 'V0-1', 'V0', 'V0+', 'V1', 'V1', 'V3', 'V0', 'V1',
#        'V2', 'V2', 'V2', 'V2', 'V4', 'V0-', 'V0', 'V0', 'V0', 'V0-1',
#        'V2', 'V3', 'V0', 'V0-1', 'V0-1', 'V0-1', 'V0-1', 'V0-1', 'V0-1',
#        'V0-', 'V0', 'V0', 'V0', 'V1', 'V3', 'V0', 'V2-3', 'V4', 'V5-',
#        'V1', 'V2', 'V3', 'V2', 'V0', 'V0-1', 'V0-1 ', 'V2', 'V2-3', 'V0-',
#        'V1 ', 'V1+', 'V2 ', 'V3', 'V4 ', 'V0', 'V1', 'V1+', 'V1+', 'V2-3',
#        'V0', 'V1', 'V1+', 'V1+', 'V3- ', 'V3-', 'V3+', 'V0', 'V1', 'V1',
#        'V2', 'V3', 'V4-5', 'V0-1', 'V0', 'V3-', 'V1', 'V0', 'V0-1', 'V1',
#        'V1-2', 'V0', 'V0', 'V0', 'V0', 'V0', 'V0-1', 'V0-1', 'V0-1',
#        'V1-2', 'V1-2', 'V2-3', 'V2-3', 'V3-4 ', 'V3-4', 'V4-5', 'V0',
#        'V0', 'V3-4', 'V0-', 'V0', 'V1-', 'V2', 'V3', 'V0+', 'V1+', 'V2',
#        'V0-1', 'V0', 'V0', 'V0', 'V0', 'V0', 'V0-1 ', 'V1-', 'V1-2 ',
#        'V0 ', 'V0+', 'V2', 'V4', 'V0 ', 'V0', 'V0 ', 'V0', 'V0+', 'V0+',
#        'V0', 'V0 ', 'V0-1 ', 'V0-1 ', 'V1', 'V1', 'V2-', 'V3', 'V3+',
#        'V4', 'V4+', 'V5', 'V0', 'V1', 'V2', 'V2+', 'V3', 'V3 ', 'V4+',
#        'V0-1', 'V1-', 'V2+', 'V7', 'V0', 'V1', 'V1', 'V1+', 'V2-3',
#        'V3-4', 'V4', 'V0', 'V2', 'V0-', 'V1-', 'V1', 'V1', 'V1', 'V1',
#        'V2', 'V2', 'V2+', 'V3-4', 'V0-1 ', 'V1', 'V1', 'V2'], dtype=object)

# %%
combined_chart
# Out:
#                  Route                                                URL  \
# 0           Polar Bear  https://www.mountainproject.com/route/11178633...
# 1                  Axe  https://www.mountainproject.com/route/11178636...
# 2             Lazy Day  https://www.mountainproject.com/route/11178638...
# 3              Hatchet  https://www.mountainproject.com/route/11796064...
# 4              unnamed  https://www.mountainproject.com/route/11133249...
# ..                 ...                                                ...
# 50  Beneath The Cheeks  https://www.mountainproject.com/route/12072811...
# 51            Rib Cage  https://www.mountainproject.com/route/11894051...
# 52    Front And Center  https://www.mountainproject.com/route/12081417...
# 53   Not The Backboard  https://www.mountainproject.com/route/12081421...
# 54      Good Dirty Fun  https://www.mountainproject.com/route/12081419...
#
#    Route Type Rating  Area Latitude  Area Longitude  \
# 0     Boulder    V0        40.47547       -74.70160
# 1     Boulder     V0       40.47547       -74.70160
# 2     Boulder     V0       40.47547       -74.70160
# 3     Boulder     V0       40.47547       -74.70160
# 4     Boulder    V0+       40.47547       -74.70160
# ..        ...    ...            ...             ...
# 50    Boulder   V3-4       39.76853       -75.57480
# 51    Boulder  V0-1        39.77404       -75.51579
# 52    Boulder     V1       39.75675       -75.55106
# 53    Boulder     V1       39.75675       -75.55106
# 54    Boulder     V2       39.75675       -75.55106
#
#                                           Description       State  \
# 0                                       Not available  New Jersey
# 1                                       Not available  New Jersey
# 2                                       Not available  New Jersey
# 3   Same SDS as Axe to the right of the arête. Mak...  New Jersey
# 4                                       Not available  New Jersey
# ..                                                ...         ...
# 50  A very low sit start to either Flex-a-flake or...    Delaware
# 51  The crux is the middle of the face, the crack ...    Delaware
# 52  Start in the very venter of the boulder with h...    Delaware
# 53  Sit Start with hands on the good blocky ledge....    Delaware
# 54  Sit start hanging on the good blocky edge belo...    Delaware
#
#                              Gorge                      Area  \
# 0                        Mid-state   Bouldering Mid-State Nj
# 1                        Mid-state   Bouldering Mid-State Nj
# 2                        Mid-state   Bouldering Mid-State Nj
# 3                        Mid-state   Bouldering Mid-State Nj
# 4                        Mid-state   Bouldering Mid-State Nj
# ..                             ...                       ...
# 50                   Rockford Park                Lower Tier
# 51  Rockwood Park / Greenway Trail                       N/A
# 52                 Brandywine Park  Front And Center Boulder
# 53                 Brandywine Park  Front And Center Boulder
# 54                 Brandywine Park  Front And Center Boulder
#
#                           Crag     Subcrag
# 0   Sourland Mountain Preserve  Southfield
# 1   Sourland Mountain Preserve  Southfield
# 2   Sourland Mountain Preserve  Southfield
# 3   Sourland Mountain Preserve  Southfield
# 4   Sourland Mountain Preserve  Southfield
# ..                         ...         ...
# 50                         N/A         N/A
# 51                         N/A         N/A
# 52                         N/A         N/A
# 53                         N/A         N/A
# 54                         N/A         N/A
#
# [685 rows x 12 columns]

# %%
combined_chart['Gorge'] = combined_chart['Gorge'].str.replace('e. South','South')
# Out:
# /var/folders/b8/qw7xf4r16w383xrhw3980l4w0000gp/T/ipykernel_14194/4040374966.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   combined_chart['Gorge'] = combined_chart['Gorge'].str.replace('e. South','South')

# %%
combined_chart['Gorge'].values
# Out:
# array(['Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state',
#        'Mid-state', 'Mid-state', 'Mid-state', 'Mid-state', 'South',
#        'South', 'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Southeastern Lowlands',
#        'Southeastern Lowlands', 'Alapocas Run State Park',
#        'Alapocas Run State Park', 'Alapocas Run State Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockford Park', 'Rockford Park', 'Rockford Park', 'Rockford Park',
#        'Rockwood Park / Greenway Trail', 'Brandywine Park',
#        'Brandywine Park', 'Brandywine Park'], dtype=object)

# %%
combined_chart['Rating'] = combined_chart['Rating'].str.strip()

# %%
combined_chart['Rating'].value_counts()
# Out:
# V0      106
# V1       86
# V2       80
# V3       54
# V4       47
# V0-1     35
# V5       30
# V0+      29
# V0-      25
# V6       25
# V1+      22
# V7       20
# V8       16
# V1-2     10
# V1-      10
# V2-3     10
# V4-5      9
# V3+       9
# V2+       8
# V3-4      7
# V5-       5
# V3-       5
# V9        5
# V5+       4
# V6-7      3
# V2-       3
# V5-6      3
# V4+       3
# V10       3
# V4-       2
# V11       2
# V6+       2
# V10-      1
# V8-9      1
# V7-8      1
# V2 X      1
# V8-       1
# V7-       1
# V8+       1
# Name: Rating, dtype: int64

# %%
print(combined_chart[combined_chart['Rating']=='V2 X'].index.values)
# Out:
# [35]

# %%
combined_chart['Rating'][35] = 'V2'
# Out:
# /var/folders/b8/qw7xf4r16w383xrhw3980l4w0000gp/T/ipykernel_14194/1050504452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_chart['Rating'][35] = 'V2'

# %%
combined_chart['Rating'].value_counts()
# Out:
# V0      106
# V1       85
# V2       83
# V3       54
# V4       47
# V0-1     35
# V5       30
# V0+      29
# V0-      25
# V6       25
# V1+      21
# V7       20
# V8       16
# V1-2     10
# V1-      10
# V2-3     10
# V3+       9
# V4-5      9
# V2+       8
# V3-4      7
# V5-       5
# V3-       5
# V9        5
# V5+       4
# V2-       3
# V5-6      3
# V4+       3
# V10       3
# V6-7      3
# V4-       2
# V11       2
# V6+       2
# V8-9      1
# V8+       1
# V10-      1
# V7-8      1
# V8-       1
# V7-       1
# Name: Rating, dtype: int64

# %%
combined_chart = combined_chart.rename(columns={'Rating':'Grading'})

# %%
combined_chart
# Out:
#                  Route                                                URL  \
# 0           Polar Bear  https://www.mountainproject.com/route/11178633...
# 1                  Axe  https://www.mountainproject.com/route/11178636...
# 2             Lazy Day  https://www.mountainproject.com/route/11178638...
# 3              Hatchet  https://www.mountainproject.com/route/11796064...
# 4              unnamed  https://www.mountainproject.com/route/11133249...
# ..                 ...                                                ...
# 50  Beneath The Cheeks  https://www.mountainproject.com/route/12072811...
# 51            Rib Cage  https://www.mountainproject.com/route/11894051...
# 52    Front And Center  https://www.mountainproject.com/route/12081417...
# 53   Not The Backboard  https://www.mountainproject.com/route/12081421...
# 54      Good Dirty Fun  https://www.mountainproject.com/route/12081419...
#
#    Route Type Grading  Area Latitude  Area Longitude  \
# 0     Boulder      V0       40.47547       -74.70160
# 1     Boulder      V0       40.47547       -74.70160
# 2     Boulder      V0       40.47547       -74.70160
# 3     Boulder      V0       40.47547       -74.70160
# 4     Boulder     V0+       40.47547       -74.70160
# ..        ...     ...            ...             ...
# 50    Boulder    V3-4       39.76853       -75.57480
# 51    Boulder    V0-1       39.77404       -75.51579
# 52    Boulder      V1       39.75675       -75.55106
# 53    Boulder      V1       39.75675       -75.55106
# 54    Boulder      V2       39.75675       -75.55106
#
#                                           Description       State  \
# 0                                       Not available  New Jersey
# 1                                       Not available  New Jersey
# 2                                       Not available  New Jersey
# 3   Same SDS as Axe to the right of the arête. Mak...  New Jersey
# 4                                       Not available  New Jersey
# ..                                                ...         ...
# 50  A very low sit start to either Flex-a-flake or...    Delaware
# 51  The crux is the middle of the face, the crack ...    Delaware
# 52  Start in the very venter of the boulder with h...    Delaware
# 53  Sit Start with hands on the good blocky ledge....    Delaware
# 54  Sit start hanging on the good blocky edge belo...    Delaware
#
#                              Gorge                      Area  \
# 0                        Mid-state   Bouldering Mid-State Nj
# 1                        Mid-state   Bouldering Mid-State Nj
# 2                        Mid-state   Bouldering Mid-State Nj
# 3                        Mid-state   Bouldering Mid-State Nj
# 4                        Mid-state   Bouldering Mid-State Nj
# ..                             ...                       ...
# 50                   Rockford Park                Lower Tier
# 51  Rockwood Park / Greenway Trail                       N/A
# 52                 Brandywine Park  Front And Center Boulder
# 53                 Brandywine Park  Front And Center Boulder
# 54                 Brandywine Park  Front And Center Boulder
#
#                           Crag     Subcrag
# 0   Sourland Mountain Preserve  Southfield
# 1   Sourland Mountain Preserve  Southfield
# 2   Sourland Mountain Preserve  Southfield
# 3   Sourland Mountain Preserve  Southfield
# 4   Sourland Mountain Preserve  Southfield
# ..                         ...         ...
# 50                         N/A         N/A
# 51                         N/A         N/A
# 52                         N/A         N/A
# 53                         N/A         N/A
# 54                         N/A         N/A
#
# [685 rows x 12 columns]

# %%
#moving route name to front of chart
columns = combined_chart.columns.to_list()
columns
# Out:
# ['Route',
#  'URL',
#  'Route Type',
#  'Grading',
#  'Area Latitude',
#  'Area Longitude',
#  'Description',
#  'State',
#  'Gorge',
#  'Area',
#  'Crag',
#  'Subcrag']

# %%
columns.insert(0, columns.pop(columns.index('Route')))
columns.insert(11, columns.pop(columns.index('Description')))
columns.insert(11, columns.pop(columns.index('URL')))

# %%
columns
# Out:
# ['Route',
#  'Route Type',
#  'Grading',
#  'Area Latitude',
#  'Area Longitude',
#  'State',
#  'Gorge',
#  'Area',
#  'Crag',
#  'Subcrag',
#  'Description',
#  'URL']

# %%
combined_chart = combined_chart[columns]

# %%
combined_chart.head()
# Out:
#         Route Route Type Grading  Area Latitude  Area Longitude       State  \
# 0  Polar Bear    Boulder      V0       40.47547        -74.7016  New Jersey
# 1         Axe    Boulder      V0       40.47547        -74.7016  New Jersey
# 2    Lazy Day    Boulder      V0       40.47547        -74.7016  New Jersey
# 3     Hatchet    Boulder      V0       40.47547        -74.7016  New Jersey
# 4     unnamed    Boulder     V0+       40.47547        -74.7016  New Jersey
#
#        Gorge                     Area                        Crag     Subcrag  \
# 0  Mid-state  Bouldering Mid-State Nj  Sourland Mountain Preserve  Southfield
# 1  Mid-state  Bouldering Mid-State Nj  Sourland Mountain Preserve  Southfield
# 2  Mid-state  Bouldering Mid-State Nj  Sourland Mountain Preserve  Southfield
# 3  Mid-state  Bouldering Mid-State Nj  Sourland Mountain Preserve  Southfield
# 4  Mid-state  Bouldering Mid-State Nj  Sourland Mountain Preserve  Southfield
#
#                                          Description  \
# 0                                      Not available
# 1                                      Not available
# 2                                      Not available
# 3  Same SDS as Axe to the right of the arête. Mak...
# 4                                      Not available
#
#                                                  URL
# 0  https://www.mountainproject.com/route/11178633...
# 1  https://www.mountainproject.com/route/11178636...
# 2  https://www.mountainproject.com/route/11178638...
# 3  https://www.mountainproject.com/route/11796064...
# 4  https://www.mountainproject.com/route/11133249...

# %%
combined_chart.tail()
# Out:
#                  Route Route Type Grading  Area Latitude  Area Longitude  \
# 50  Beneath The Cheeks    Boulder    V3-4       39.76853       -75.57480
# 51            Rib Cage    Boulder    V0-1       39.77404       -75.51579
# 52    Front And Center    Boulder      V1       39.75675       -75.55106
# 53   Not The Backboard    Boulder      V1       39.75675       -75.55106
# 54      Good Dirty Fun    Boulder      V2       39.75675       -75.55106
#
#        State                           Gorge                      Area Crag  \
# 50  Delaware                   Rockford Park                Lower Tier  N/A
# 51  Delaware  Rockwood Park / Greenway Trail                       N/A  N/A
# 52  Delaware                 Brandywine Park  Front And Center Boulder  N/A
# 53  Delaware                 Brandywine Park  Front And Center Boulder  N/A
# 54  Delaware                 Brandywine Park  Front And Center Boulder  N/A
#
#    Subcrag                                        Description  \
# 50     N/A  A very low sit start to either Flex-a-flake or...
# 51     N/A  The crux is the middle of the face, the crack ...
# 52     N/A  Start in the very venter of the boulder with h...
# 53     N/A  Sit Start with hands on the good blocky ledge....
# 54     N/A  Sit start hanging on the good blocky edge belo...
#
#                                                   URL
# 50  https://www.mountainproject.com/route/12072811...
# 51  https://www.mountainproject.com/route/11894051...
# 52  https://www.mountainproject.com/route/12081417...
# 53  https://www.mountainproject.com/route/12081421...
# 54  https://www.mountainproject.com/route/12081419...

# %%
combined_chart['Route Type'] = 'Boulder'

# %%
combined_chart = combined_chart.reset_index()

# %%
combined_chart.columns
# Out:
# Index(['index', 'Route', 'Route Type', 'Grading', 'Area Latitude',
#        'Area Longitude', 'State', 'Gorge', 'Area', 'Crag', 'Subcrag',
#        'Description', 'URL'],
#       dtype='object')

# %%
combined_chart = combined_chart.drop(columns='index')

# %%
combined_chart['Route'] = combined_chart['Route'].str.title()

# %%
combined_chart.to_csv('combined_route_chart.csv')
